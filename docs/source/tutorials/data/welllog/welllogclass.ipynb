# %% [markdown]
# # The WellLog class
#
# The WellLog class inherits from ScalarField, leveraging all its capabilities to manage scalar data
# alongside coordinates, while allowing for further customization specific to well logging workflows.
