# %%
import ipyparallel as ipp

# Create an MPI cluster with 8 engines
cluster = ipp.Cluster(engines="mpi", n=8)

# Start and connect to the cluster
rc = cluster.start_and_connect_sync()

# Enable IPython magics for parallel processing
rc[:].activate()
# Out:
# Starting 8 engines with <class 'ipyparallel.cluster.launcher.MPIEngineSetLauncher'>
#   0%|          | 0/8 [00:00<?, ?engine/s]

# %%
# %%px --block
#
# import numpy as np
# import h5py
# import rockverse as rv
#
# shape=(5,2,8)
# a = rv.create_array(shape=shape, dtype=np.float32, chunk_shape=(2,2,2))
# a[...] = np.random.rand(*shape)
# a.zarray[...]
# a[...]
#
# filename = r"C:\Users\GOB7\Downloads\test.h5"
# path='/my/awesome/array'
# self=a
# self.h5_dump(filename, path='/my/awesome/array', mode='w')
#
# with h5py.File(filename, 'r') as fobj:
#     b = fobj['/my/awesome/array'][...]
#     c = {k: v for k, v in fobj['/my/awesome/array'].attrs.items()}
# b == a[...]
# c
# Out:
# %px:   0%|          | 0/8 [00:00<?, ?tasks/s]
# Out[2:1]: {'_ROCKVERSE_DATATYPE': 'ParallelArray'}
# Out[0:1]: {'_ROCKVERSE_DATATYPE': 'ParallelArray'}
# Out[1:1]: {'_ROCKVERSE_DATATYPE': 'ParallelArray'}
# Out[4:1]: {'_ROCKVERSE_DATATYPE': 'ParallelArray'}
# Out[3:1]: {'_ROCKVERSE_DATATYPE': 'ParallelArray'}
# Out[7:1]: {'_ROCKVERSE_DATATYPE': 'ParallelArray'}
# Out[5:1]: {'_ROCKVERSE_DATATYPE': 'ParallelArray'}
# Out[6:1]: {'_ROCKVERSE_DATATYPE': 'ParallelArray'}

# %%
# %%px --block
# %tb
#
# a.attrs.asdict()
# Out:
# [0:execute]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Downloads\rockverse\src\rockverse\errors.py:40, in collective_only_rank0_runs(id)
#      39 try:
# ---> 40     yield
#      41 except Exception as e:
#
# File ~\Downloads\rockverse\src\rockverse\core\attributes.py:86, in Attributes.asdict(self)
#      85     if mpi_rank == 0:
# ---> 86         value = {k: v for k, v in self._zobj.attrs}
#      87 value = comm.bcast(value, root=0)
#
# ValueError: too many values to unpack (expected 2)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 a.attrs.asdict()
#
# File ~\Downloads\rockverse\src\rockverse\core\attributes.py:84, in Attributes.asdict(self)
#      82 def asdict(self):
#      83     value = None
# ---> 84     with collective_only_rank0_runs():
#      85         if mpi_rank == 0:
#      86             value = {k: v for k, v in self._zobj.attrs}
#
# File ~\AppData\Local\miniforge3\envs\rockverse\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     156     value = typ()
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#     163     return exc is not value
#
# File ~\Downloads\rockverse\src\rockverse\errors.py:46, in collective_only_rank0_runs(id)
#      44 if error_msg:
#      45     name, msg = error_msg.split(':')[0].strip(), ''.join(error_msg.split(':')[1:]).strip()
# ---> 46     collective_raise(CustomCollectiveException(name, msg))
#
# File ~\Downloads\rockverse\src\rockverse\errors.py:15, in collective_raise(e)
#      13 def collective_raise(e):
#      14     if mpi_rank == 0:
# ---> 15         raise e
#      16     else:
#      17         sys.exit(1)
#
# ValueError: too many values to unpack (expected 2)
# [0:execute]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Downloads\rockverse\src\rockverse\errors.py:40, in collective_only_rank0_runs(id)
#      39 try:
# ---> 40     yield
#      41 except Exception as e:
#
# File ~\Downloads\rockverse\src\rockverse\core\attributes.py:86, in Attributes.asdict(self)
#      85     if mpi_rank == 0:
# ---> 86         value = {k: v for k, v in self._zobj.attrs}
#      87 value = comm.bcast(value, root=0)
#
# ValueError: too many values to unpack (expected 2)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 get_ipython().run_line_magic('tb', '')
# ----> 3 a.attrs.asdict()
#
# File ~\Downloads\rockverse\src\rockverse\core\attributes.py:84, in Attributes.asdict(self)
#      82 def asdict(self):
#      83     value = None
# ---> 84     with collective_only_rank0_runs():
#      85         if mpi_rank == 0:
#      86             value = {k: v for k, v in self._zobj.attrs}
#
# File ~\AppData\Local\miniforge3\envs\rockverse\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     156     value = typ()
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#     163     return exc is not value
#
# File ~\Downloads\rockverse\src\rockverse\errors.py:46, in collective_only_rank0_runs(id)
#      44 if error_msg:
#      45     name, msg = error_msg.split(':')[0].strip(), ''.join(error_msg.split(':')[1:]).strip()
# ---> 46     collective_raise(CustomCollectiveException(name, msg))
#
# File ~\Downloads\rockverse\src\rockverse\errors.py:15, in collective_raise(e)
#      13 def collective_raise(e):
#      14     if mpi_rank == 0:
# ---> 15         raise e
#      16     else:
#      17         sys.exit(1)
#
# ValueError: too many values to unpack (expected 2)
# [1:execute]
# ---------------------------------------------------------------------------
# SystemExit                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 a.attrs.asdict()
#
# File ~\Downloads\rockverse\src\rockverse\core\attributes.py:84, in Attributes.asdict(self)
#      82 def asdict(self):
#      83     value = None
# ---> 84     with collective_only_rank0_runs():
#      85         if mpi_rank == 0:
#      86             value = {k: v for k, v in self._zobj.attrs}
#
# File ~\AppData\Local\miniforge3\envs\rockverse\Lib\contextlib.py:144, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142 if typ is None:
#     143     try:
# --> 144         next(self.gen)
#     145     except StopIteration:
#     146         return False
#
# File ~\Downloads\rockverse\src\rockverse\errors.py:46, in collective_only_rank0_runs(id)
#      44 if error_msg:
#      45     name, msg = error_msg.split(':')[0].strip(), ''.join(error_msg.split(':')[1:]).strip()
# ---> 46     collective_raise(CustomCollectiveException(name, msg))
#
# File ~\Downloads\rockverse\src\rockverse\errors.py:17, in collective_raise(e)
#      15     raise e
#      16 else:
# ---> 17     sys.exit(1)
#
# SystemExit: 1
# [2:execute]
# ---------------------------------------------------------------------------
# SystemExit                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 a.attrs.asdict()
#
# File ~\Downloads\rockverse\src\rockverse\core\attributes.py:84, in Attributes.asdict(self)
#      82 def asdict(self):
#      83     value = None
# ---> 84     with collective_only_rank0_runs():
#      85         if mpi_rank == 0:
#      86             value = {k: v for k, v in self._zobj.attrs}
#
# File ~\AppData\Local\miniforge3\envs\rockverse\Lib\contextlib.py:144, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142 if typ is None:
#     143     try:
# --> 144         next(self.gen)
#     145     except StopIteration:
#     146         return False
#
# File ~\Downloads\rockverse\src\rockverse\errors.py:46, in collective_only_rank0_runs(id)
#      44 if error_msg:
#      45     name, msg = error_msg.split(':')[0].strip(), ''.join(error_msg.split(':')[1:]).strip()
# ---> 46     collective_raise(CustomCollectiveException(name, msg))
#
# File ~\Downloads\rockverse\src\rockverse\errors.py:17, in collective_raise(e)
#      15     raise e
#      16 else:
# ---> 17     sys.exit(1)
#
# SystemExit: 1
# [4:execute] SystemExit: 1
# [1:execute] SystemExit: 1
# [2:execute] SystemExit: 1
# [4:execute] SystemExit: 1
# [3:execute] SystemExit: 1
# [3:execute] SystemExit: 1
# [5:execute] SystemExit: 1
# [5:execute] SystemExit: 1
# [6:execute] SystemExit: 1
# [7:execute] SystemExit: 1
# [6:execute] SystemExit: 1
# [7:execute] SystemExit: 1
# 8 errors
