# %%
import ipyparallel as ipp

# Create an MPI cluster with 8 engines
cluster = ipp.Cluster(engines="mpi", n=8)

# Start and connect to the cluster
rc = cluster.start_and_connect_sync()

# Enable IPython magics for parallel processing
rc[:].activate()
# Out:
# Starting 8 engines with <class 'ipyparallel.cluster.launcher.MPIEngineSetLauncher'>
#   0%|          | 0/8 [00:00<?, ?engine/s]

# %%
# %%px --block
#
# import numpy as np
# import h5py
# import rockverse as rv
#
# shape=(5,2,8)
# a = rv.create_array(shape=shape, dtype=np.float32, chunk_shape=(2,2,2))
# a[...] = np.random.rand(*shape)
# a.zarray[...]
# a[...]
#
# filename = r"C:\Users\GOB7\Downloads\test.h5"
# path='/my/awesome/array'
# self=a
# self.h5_dump(filename, path='/my/awesome/array', mode='w')
#
# with h5py.File(filename, 'r') as fobj:
#     b = fobj['/my/awesome/array'][...]
#     c = {k: v for k, v in fobj['/my/awesome/array'].attrs.items()}
# b == a[...]
# c
# Out:
# Out[2:7]: {'_ROCKVERSE_DATATYPE': 'ParallelArray'}
# Out[1:7]: {'_ROCKVERSE_DATATYPE': 'ParallelArray'}
# Out[4:7]: {'_ROCKVERSE_DATATYPE': 'ParallelArray'}
# Out[5:7]: {'_ROCKVERSE_DATATYPE': 'ParallelArray'}
# Out[6:7]: {'_ROCKVERSE_DATATYPE': 'ParallelArray'}
# Out[3:7]: {'_ROCKVERSE_DATATYPE': 'ParallelArray'}
# Out[0:7]: {'_ROCKVERSE_DATATYPE': 'ParallelArray'}
# Out[7:7]: {'_ROCKVERSE_DATATYPE': 'ParallelArray'}

# %%
# %%px --block
# %tb
#
# a.coordinates[0]
# Out:
# [0:execute]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 3
#       1 get_ipython().run_line_magic('tb', '')
# ----> 3 a.coordinates[0]
#
# AttributeError: 'ParallelArray' object has no attribute 'coordinates'
# [1:execute]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 3
#       1 get_ipython().run_line_magic('tb', '')
# ----> 3 a.coordinates[0]
#
# AttributeError: 'ParallelArray' object has no attribute 'coordinates'
# [0:execute]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 3
#       1 get_ipython().run_line_magic('tb', '')
# ----> 3 a.coordinates[0]
#
# AttributeError: 'ParallelArray' object has no attribute 'coordinates'
# [4:execute]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 3
#       1 get_ipython().run_line_magic('tb', '')
# ----> 3 a.coordinates[0]
#
# AttributeError: 'ParallelArray' object has no attribute 'coordinates'
# [2:execute] AttributeError: 'ParallelArray' object has no attribute 'coordinates'
# [5:execute] AttributeError: 'ParallelArray' object has no attribute 'coordinates'
# [6:execute] AttributeError: 'ParallelArray' object has no attribute 'coordinates'
# [7:execute] AttributeError: 'ParallelArray' object has no attribute 'coordinates'
# [2:execute] AttributeError: 'ParallelArray' object has no attribute 'coordinates'
# [6:execute] AttributeError: 'ParallelArray' object has no attribute 'coordinates'
# [5:execute] AttributeError: 'ParallelArray' object has no attribute 'coordinates'
# [7:execute] AttributeError: 'ParallelArray' object has no attribute 'coordinates'
# [1:execute] AttributeError: 'ParallelArray' object has no attribute 'coordinates'
# [3:execute] AttributeError: 'ParallelArray' object has no attribute 'coordinates'
# [3:execute] AttributeError: 'ParallelArray' object has no attribute 'coordinates'
# [4:execute] AttributeError: 'ParallelArray' object has no attribute 'coordinates'
# 8 errors
