# %% [markdown]
# Restarted rockverse (Python 3.12.11)

# %%
import ipyparallel as ipp

# Create an MPI cluster with 4 engines
cluster = ipp.Cluster(engines="mpi", n=4)

# Start and connect to the cluster
rc = cluster.start_and_connect_sync()

# Enable IPython magics for parallel processing
rc[:].activate()
# Out:
# Starting 4 engines with <class 'ipyparallel.cluster.launcher.MPIEngineSetLauncher'>
#   0%|          | 0/4 [00:00<?, ?engine/s]

# %%
# %%px --block
# import rockverse as rv
# self = rv.cwls_las_sample()

# %%
# %%px --block
# self._find_path('*')
# Out:
# Out[2:2]:
# ['Well/STRT',
#  'Well/STOP',
#  'Well/STEP',
#  'Well/NULL',
#  'Well/COMP',
#  'Well/WELL',
#  'Well/FLD',
#  'Well/LOC',
#  'Well/SRVC',
#  'Well/DATE',
#  'Well/CTRY',
#  'Well/PROV',
#  'Well/UWI',
#  'Well/LIC',
#  'Well/LATI',
#  'Well/LONG',
#  'Well/GDAT',
#  '|- Curve',
#  'Curve/|- parameters:',
#  'Curve/|   |-[0] PDAT: GL (Permanent Data)',
#  'Curve/|   |-[1] APD: 4.2 M (Above Permanent Data)',
#  'Curve/|   |-[2] DREF: KB (Depth Reference (KB,DF,CB))',
#  'Curve/|   |-[3] EREF: 234.5 M (Elevation of Depth Reference)',
#  'Curve/|   |-[4] RUN: 1 (Run Number)',
#  'Curve/|   |-[5] RUNS: 2 (# of Runs for this well.)',
#  'Curve/|   |-[6] RUN[1]: 2 (Number of the indexed RUN)',
#  'Curve/|   |-[7] RUN[2]: 3 (Number of the indexed RUN)',
#  'Curve/|   |-[8] RUN_Depth[1]: (0.0, 1500.0) M (Run 1 Depth Interval)',
#  'Curve/|   |-[9] RUN_Depth[2]: (1500.0, 2513.0) M (Run 2 Depth Interval)',
#  'Curve/|   |-[10] NMAT_Depth[1]: (523.0, 1500.0) M (Neutron Matrix Depth interval)',
#  'Curve/|   |-[11] NMAT_Depth[2]: (1500.0, 2500.0) M (Neutron Matrix Depth interval)',
#  'Curve/|   |-[12] DMAT_Depth[1]: (523.0, 1510.0) M (Density Matrix Depth interval)',
#  'Curve/|   |-[13] DMAT_Depth[2]: (1510.0, 2510.0) M (Density Matrix Depth interval)',
#  'Curve/|   |-[14] MATR[1]: SAND (Neutron Porosity Matrix)',
#  'Curve/|   |-[15] MATR[2]: LIME (Neutron Porosity Matrix)',
#  'Curve/|   |-[16] MDEN[1]: 2650 KG/M3 (Neutron Porosity Matrix)',
#  'Curve/|   |-[17] MDEN[2]: 2710 KG/M3 (Neutron Porosity Matrix)',
#  'Curve/|   |-[18] FR_LR[1]: 500,100 M',
#  'Curve/|   |-[19] FR_LR[2]: 523,100 M',
#  'Curve/|   |-[20] FR_LR[3]: 520,100 M',
#  'Curve/|   |-[21] FR_LR[4]: 500,100 M',
#  'Curve/|   |-[22] FR_LR[5] M',
#  'Curve/|   |-[23] FR_LR[6]: 510,100 M',
#  'Curve/|   |-[24] FR_LR[7]: 510,100 M',
#  'Curve/|   |-[25] FR_LR[8]: 510,100 M',
#  'Curve/|   |-[26] FR_LR[9]: 510,100 M',
#  'Curve/|   |-[27] FR_LR[10]: 510,100 M',
#  'Curve/|   |-[28] TDL M (Total Depth Logger)',
#  'Curve/|   |-[29] TDD M (Total Depth Driller)',
#  'Curve/|   |-[30] CSGL M (Casing Bottom Logger)',
#  'Curve/|   |-[31] CSGD M (Casing Bottom Driller)',
#  'Curve/|   |-[32] CSGS MM (Casing Size)',
#  'Curve/|   |-[33] CSGW KG/M (Casing Weight)',
#  'Curve/|   |-[34] BS MM (Bit Size)',
#  'Curve/|   |-[35] MUD (Mud type)',
#  'Curve/|   |-[36] MUDS (Mud Source)',
#  'Curve/|   |-[37] MUDD KG/M3 (Mud Density)',
#  'Curve/|   |-[38] MUDV S (Mud Viscosity (Funnel))',
#  'Curve/|   |-[39] FL CC (Fluid Loss)',
#  'Curve/|   |-[40] PH (PH)',
#  'Curve/|   |-[41] RM OHMM (Resistivity of Mud)',
#  'Curve/|   |-[42] RMT DEGC (Temperature of Mud)',
#  'Curve/|   |-[43] RMF OHMM (Rest. of Mud Filtrate)',
#  'Curve/|   |-[44] RMFT DEGC (Temp. of Mud Filtrate)',
#  'Curve/|   |-[45] RMC OHMM (Rest. of Mud Cake)',
#  'Curve/|   |-[46] RMCT DEGC (Temp. of Mud Cake)',
#  'Curve/|   |-[47] TMAX DEGC (Max. Recorded Temp.)',
#  'Curve/|   |-[48] TIMC (Date/Time Circulation Stopped)',
#  'Curve/|   |-[49] TIML (Date/Time Logger Tagged Bottom)',
#  'Curve/|   |-[50] UNIT (Logging Unit Number)',
#  'Curve/|   |-[51] BASE (Home Base of Logging Unit)',
#  'Curve/|   |-[52] ENG (Recording Engineer)',
#  'Curve/|   |-[53] WIT (Witnessed By)',
#  'Curve/|   |-[54] TDL M (Total Depth Logger)',
#  'Curve/|   |-[55] TDD M (Total Depth Driller)',
#  'Curve/|   |-[56] CSGL M (Casing Bottom Logger)',
#  'Curve/|   |-[57] CSGD M (Casing Bottom Driller)',
#  'Curve/|   |-[58] CSGS MM (Casing Size)',
#  'Curve/|   |-[59] CSGW KG/M (Casing Weight)',
#  'Curve/|   |-[60] BS MM (Bit Size)',
#  'Curve/|   |-[61] MUD (Mud type)',
#  'Curve/|   |-[62] MUDS (Mud Source)',
#  'Curve/|   |-[63] MUDD KG/M3 (Mud Density)',
#  'Curve/|   |-[64] MUDV S (Mud Viscosity (Funnel))',
#  'Curve/|   |-[65] FL CC (Fluid Loss)',
#  'Curve/|   |-[66] PH (PH)',
#  'Curve/|   |-[67] RM OHMM (Resistivity of Mud)',
#  'Curve/|   |-[68] RMT DEGC (Temperature of Mud)',
#  'Curve/|   |-[69] RMF OHMM (Rest. of Mud Filtrate)',
#  'Curve/|   |-[70] RMFT DEGC (Temp. of Mud Filtrate)',
#  'Curve/|   |-[71] RMC OHMM (Rest. of Mud Cake)',
#  'Curve/|   |-[72] RMCT DEGC (Temp. of Mud Cake)',
#  'Curve/|   |-[73] TMAX DEGC (Max. Recorded Temp.)',
#  'Curve/|   |-[74] TIMC (Date/Time Circulation Stopped)',
#  'Curve/|   |-[75] TIML (Date/Time Logger Tagged Bottom)',
#  'Curve/|   |-[76] UNIT (Logging Unit Number)',
#  'Curve/|   |-[77] BASE (Home Base of Logging Unit)',
#  'Curve/|   |-[78] ENG (Recording Engineer)',
#  'Curve/|   |-[79] WIT (Witnessed By)',
#  'Curve/|- data:',
#  'Curve/|   |-[0] DEPT, M: DEPTH',
#  'Curve/|   |-[1] DT, US/M (123 456 789): SONIC TRANSIT TIME',
#  "Curve/|   |-[2] DPHI, V/V (123 456 789): DENSITY POROSITY | ('MDEN[1]', 'MDEN[2]')",
#  "Curve/|   |-[3] NPHI, V/V (123 456 789): NEUTRON POROSITY | ('MATR[1]', 'MATR[2]')",
#  'Curve/|   |-[4] YME, PA (123 456 789): YOUNGS MODULES',
#  'Curve/|   |-[5] CDES (123 456 789): CORE DESCRIPTION',
#  'Curve/|   |-[6] NMR[1], mv (123 456 789): NMR Echo Array',
#  'Curve/|   |-[7] NMR[2], mv (123 456 789): NMR Echo Array',
#  'Curve/|   |-[8] NMR[3], mv (123 456 789): NMR Echo Array',
#  'Curve/|   |-[9] NMR[4], mv (123 456 789): NMR Echo Array',
#  'Curve/|   |-[10] NMR[5], mv (123 456 789): NMR Echo Array',
#  '|- Drilling_Data',
#  'Drilling_Data/|- parameters:',
#  'Drilling_Data/|   |-[0] RIG: BIG RIG (Drilling Rig name)',
#  'Drilling_Data/|   |-[1] CONTR: DLR DRILLING (Contractor)',
#  'Drilling_Data/|- data:',
#  'Drilling_Data/|   |-[0] DEPT, ft: Depth',
#  'Drilling_Data/|   |-[1] DIST, ft: Cumulative increment of drilling.',
#  'Drilling_Data/|   |-[2] HRS, hour: Hours of drilling',
#  'Drilling_Data/|   |-[3] ROP, ft/hr: Rate of Penetration',
#  'Drilling_Data/|   |-[4] WOB, klb: Weight on bit',
#  'Drilling_Data/|   |-[5] RPM, RPM: Rotations per minute',
#  'Drilling_Data/|   |-[6] TQ, AMPS: Torque on bit in amps',
#  'Drilling_Data/|   |-[7] PUMP, psi: Mud pump pressure',
#  'Drilling_Data/|   |-[8] TSPM, SPM: Total strokes per minute',
#  'Drilling_Data/|   |-[9] GPM, gal/min: Gallons per minute',
#  'Drilling_Data/|   |-[10] ECD, ppg: Effective circulation density',
#  'Drilling_Data/|   |-[11] TBR: Total barrels returned',
#  '|- Core_Data[1]',
#  'Core_Data[1]/|- parameters:',
#  'Core_Data[1]/|   |-[0] C_SRS (Core Source)',
#  'Core_Data[1]/|   |-[1] C_TY (Core Type)',
#  'Core_Data[1]/|   |-[2] C_DT (Recovery Date (Date Core Cut))',
#  'Core_Data[1]/|   |-[3] C_TP M (Core Top Depth)',
#  'Core_Data[1]/|   |-[4] C_BS M (Core Base Depth)',
#  'Core_Data[1]/|   |-[5] C_RC M (Recovered Amount (Length))',
#  'Core_Data[1]/|   |-[6] C_FM (Primary Formation Cored)',
#  'Core_Data[1]/|   |-[7] C_DI mm (Core Diameter)',
#  'Core_Data[1]/|   |-[8] C_AC (Analyzing Company)',
#  'Core_Data[1]/|   |-[9] C_AD (Analysis Date)',
#  'Core_Data[1]/|- data:',
#  'Core_Data[1]/|   |-[0] CORT, M: Core top depth',
#  'Core_Data[1]/|   |-[1] CORB, M: Core Bottom Depth',
#  'Core_Data[1]/|   |-[2] PERM, md: Core permeability',
#  'Core_Data[1]/|   |-[3] CPOR, %: Core porosity',
#  'Core_Data[1]/|   |-[4] OIL, %: Core Oil saturation',
#  'Core_Data[1]/|   |-[5] WTR, %: Core water saturation',
#  'Core_Data[1]/|   |-[6] Oilvol, %: Core oil volume',
#  'Core_Data[1]/|   |-[7] GAS, %: Core gas saturation',
#  'Core_Data[1]/|   |-[8] WTR, %: Core water volume',
#  'Core_Data[1]/|   |-[9] CDES: Core description',
#  '|- Core_Data[2]',
#  'Core_Data[2]/|- parameters:',
#  'Core_Data[2]/|   |-[0] C_SRS (Core Source)',
#  'Core_Data[2]/|   |-[1] C_TY (Core Type)',
#  'Core_Data[2]/|   |-[2] C_DT (Recovery Date (Date Core Cut))',
#  'Core_Data[2]/|   |-[3] C_TP M (Core Top Depth)',
#  'Core_Data[2]/|   |-[4] C_BS M (Core Base Depth)',
#  'Core_Data[2]/|   |-[5] C_RC M (Recovered Amount (Length))',
#  'Core_Data[2]/|   |-[6] C_FM (Primary Formation Cored)',
#  'Core_Data[2]/|   |-[7] C_DI mm (Core Diameter)',
#  'Core_Data[2]/|   |-[8] C_AC (Analyzing Company)',
#  'Core_Data[2]/|   |-[9] C_AD (Analysis Date)',
#  'Core_Data[2]/|- data:',
#  'Core_Data[2]/|   |-[0] CORT, M: Core top depth',
#  'Core_Data[2]/|   |-[1] CORB, M: Core Bottom Depth',
#  'Core_Data[2]/|   |-[2] PERM, md: Core permeability',
#  'Core_Data[2]/|   |-[3] CPOR, PU: Core porosity',
#  '|- Inclinometry_Data',
#  'Inclinometry_Data/|- parameters:',
#  'Inclinometry_Data/|   |-[0] I_DT (SURVEY_DATE)',
#  'Inclinometry_Data/|   |-[1] I_CO (Recording Company)',
#  'Inclinometry_Data/|   |-[2] I_RF M (Depth Datum Elevation (from MSL))',
#  'Inclinometry_Data/|   |-[3] I_AT (Azimuth North Type (e.g. Grid/ True))',
#  'Inclinometry_Data/|   |-[4] I_DC DEG (Magnetic Declination (if I_AT not magnetic))',
#  'Inclinometry_Data/|   |-[5] I_KO M (Kickoff Depth (M.D. of kickoff point))',
#  'Inclinometry_Data/|   |-[6] I_GD (Geodetic datum)',
#  'Inclinometry_Data/|   |-[7] I_ONS (N/S Offset of well ref point to top hole)',
#  'Inclinometry_Data/|   |-[8] I_OEW Unit (E/W Offset of well ref point to top hole)',
#  'Inclinometry_Data/|   |-[9] I_CP (COMPUTE_METHOD (e.g. Radius of Curvature))',
#  'Inclinometry_Data/|   |-[10] I_CS (COORDINATE_SYSTEM_NAME eg UTM18N)',
#  'Inclinometry_Data/|   |-[11] TIEMD M (Tie Point Measured depth)',
#  'Inclinometry_Data/|   |-[12] TIETVD M (Tie Point True Vertical depth)',
#  'Inclinometry_Data/|   |-[13] TIEDEV M (Tie Point Deviation)',
#  'Inclinometry_Data/|   |-[14] TIEAZM M (Tie Point Azimuth)',
#  'Inclinometry_Data/|   |-[15] TIENSDR M (Tie Point North South drift)',
#  'Inclinometry_Data/|   |-[16] TIEEWDR M (Tie Point East West drift)',
#  'Inclinometry_Data/|- data:',
#  'Inclinometry_Data/|   |-[0] MD, M: Measured Depth',
#  'Inclinometry_Data/|   |-[1] TVD, M: True Vertical Depth',
#  'Inclinometry_Data/|   |-[2] AZIM, DEG: Borehole Azimuth',
#  'Inclinometry_Data/|   |-[3] DEVI, DEG: Borehole Deviation',
#  'Inclinometry_Data/|   |-[4] RB, DEG: Relative Bearing',
#  '|- Test_Data',
#  'Test_Data/|- parameters:',
#  'Test_Data/|   |-[0] TESTT: DST (Test Type)',
#  'Test_Data/|- data:',
#  'Test_Data/|   |-[0] TSTN: TEST Number',
#  'Test_Data/|   |-[1] TSTT, M: TEST Top Depth',
#  'Test_Data/|   |-[2] TSTB, M: TEST Bottom Depth',
#  'Test_Data/|   |-[3] DDES: TEST Recovery Description',
#  'Test_Data/|   |-[4] ISIP, KPAA: Initial Shut in pressure',
#  'Test_Data/|   |-[5] FSIP, KPAA: Final Shut in pressure',
#  'Test_Data/|   |-[6] RATE, BOPD: Production Rate',
#  'Test_Data/|   |-[7] BLOWD: BLOW DESCRIPTION',
#  '|- Tops_Data',
#  'Tops_Data/|- parameters:',
#  'Tops_Data/|   |-[0] TOPS: Prognosis (Formation Source)',
#  'Tops_Data/|   |-[1] TOPDR: Subsea (Tops Depth Reference)',
#  'Tops_Data/|- data:',
#  'Tops_Data/|   |-[0] TOPT, M: Formation Top Depth',
#  'Tops_Data/|   |-[1] TOPB, M: Formation Base Depth',
#  'Tops_Data/|   |-[2] TOPN: Formation Top Name',
#  '|- Perforation_Data',
#  'Perforation_Data/|- parameters:',
#  'Perforation_Data/|   |-[0] PERFTYPE: 55 gr BIG HOLE (Charge Type)',
#  'Perforation_Data/|- data:',
#  'Perforation_Data/|   |-[0] PERFT, M: Perforation Top Depth',
#  'Perforation_Data/|   |-[1] PERFB, M: Perforation Bottom Depth',
#  'Perforation_Data/|   |-[2] PERFD, SHOTS/M: Shot density per meter']
# Out[0:2]:
# ['Well/STRT',
#  'Well/STOP',
#  'Well/STEP',
#  'Well/NULL',
#  'Well/COMP',
#  'Well/WELL',
#  'Well/FLD',
#  'Well/LOC',
#  'Well/SRVC',
#  'Well/DATE',
#  'Well/CTRY',
#  'Well/PROV',
#  'Well/UWI',
#  'Well/LIC',
#  'Well/LATI',
#  'Well/LONG',
#  'Well/GDAT',
#  '|- Curve',
#  'Curve/|- parameters:',
#  'Curve/|   |-[0] PDAT: GL (Permanent Data)',
#  'Curve/|   |-[1] APD: 4.2 M (Above Permanent Data)',
#  'Curve/|   |-[2] DREF: KB (Depth Reference (KB,DF,CB))',
#  'Curve/|   |-[3] EREF: 234.5 M (Elevation of Depth Reference)',
#  'Curve/|   |-[4] RUN: 1 (Run Number)',
#  'Curve/|   |-[5] RUNS: 2 (# of Runs for this well.)',
#  'Curve/|   |-[6] RUN[1]: 2 (Number of the indexed RUN)',
#  'Curve/|   |-[7] RUN[2]: 3 (Number of the indexed RUN)',
#  'Curve/|   |-[8] RUN_Depth[1]: (0.0, 1500.0) M (Run 1 Depth Interval)',
#  'Curve/|   |-[9] RUN_Depth[2]: (1500.0, 2513.0) M (Run 2 Depth Interval)',
#  'Curve/|   |-[10] NMAT_Depth[1]: (523.0, 1500.0) M (Neutron Matrix Depth interval)',
#  'Curve/|   |-[11] NMAT_Depth[2]: (1500.0, 2500.0) M (Neutron Matrix Depth interval)',
#  'Curve/|   |-[12] DMAT_Depth[1]: (523.0, 1510.0) M (Density Matrix Depth interval)',
#  'Curve/|   |-[13] DMAT_Depth[2]: (1510.0, 2510.0) M (Density Matrix Depth interval)',
#  'Curve/|   |-[14] MATR[1]: SAND (Neutron Porosity Matrix)',
#  'Curve/|   |-[15] MATR[2]: LIME (Neutron Porosity Matrix)',
#  'Curve/|   |-[16] MDEN[1]: 2650 KG/M3 (Neutron Porosity Matrix)',
#  'Curve/|   |-[17] MDEN[2]: 2710 KG/M3 (Neutron Porosity Matrix)',
#  'Curve/|   |-[18] FR_LR[1]: 500,100 M',
#  'Curve/|   |-[19] FR_LR[2]: 523,100 M',
#  'Curve/|   |-[20] FR_LR[3]: 520,100 M',
#  'Curve/|   |-[21] FR_LR[4]: 500,100 M',
#  'Curve/|   |-[22] FR_LR[5] M',
#  'Curve/|   |-[23] FR_LR[6]: 510,100 M',
#  'Curve/|   |-[24] FR_LR[7]: 510,100 M',
#  'Curve/|   |-[25] FR_LR[8]: 510,100 M',
#  'Curve/|   |-[26] FR_LR[9]: 510,100 M',
#  'Curve/|   |-[27] FR_LR[10]: 510,100 M',
#  'Curve/|   |-[28] TDL M (Total Depth Logger)',
#  'Curve/|   |-[29] TDD M (Total Depth Driller)',
#  'Curve/|   |-[30] CSGL M (Casing Bottom Logger)',
#  'Curve/|   |-[31] CSGD M (Casing Bottom Driller)',
#  'Curve/|   |-[32] CSGS MM (Casing Size)',
#  'Curve/|   |-[33] CSGW KG/M (Casing Weight)',
#  'Curve/|   |-[34] BS MM (Bit Size)',
#  'Curve/|   |-[35] MUD (Mud type)',
#  'Curve/|   |-[36] MUDS (Mud Source)',
#  'Curve/|   |-[37] MUDD KG/M3 (Mud Density)',
#  'Curve/|   |-[38] MUDV S (Mud Viscosity (Funnel))',
#  'Curve/|   |-[39] FL CC (Fluid Loss)',
#  'Curve/|   |-[40] PH (PH)',
#  'Curve/|   |-[41] RM OHMM (Resistivity of Mud)',
#  'Curve/|   |-[42] RMT DEGC (Temperature of Mud)',
#  'Curve/|   |-[43] RMF OHMM (Rest. of Mud Filtrate)',
#  'Curve/|   |-[44] RMFT DEGC (Temp. of Mud Filtrate)',
#  'Curve/|   |-[45] RMC OHMM (Rest. of Mud Cake)',
#  'Curve/|   |-[46] RMCT DEGC (Temp. of Mud Cake)',
#  'Curve/|   |-[47] TMAX DEGC (Max. Recorded Temp.)',
#  'Curve/|   |-[48] TIMC (Date/Time Circulation Stopped)',
#  'Curve/|   |-[49] TIML (Date/Time Logger Tagged Bottom)',
#  'Curve/|   |-[50] UNIT (Logging Unit Number)',
#  'Curve/|   |-[51] BASE (Home Base of Logging Unit)',
#  'Curve/|   |-[52] ENG (Recording Engineer)',
#  'Curve/|   |-[53] WIT (Witnessed By)',
#  'Curve/|   |-[54] TDL M (Total Depth Logger)',
#  'Curve/|   |-[55] TDD M (Total Depth Driller)',
#  'Curve/|   |-[56] CSGL M (Casing Bottom Logger)',
#  'Curve/|   |-[57] CSGD M (Casing Bottom Driller)',
#  'Curve/|   |-[58] CSGS MM (Casing Size)',
#  'Curve/|   |-[59] CSGW KG/M (Casing Weight)',
#  'Curve/|   |-[60] BS MM (Bit Size)',
#  'Curve/|   |-[61] MUD (Mud type)',
#  'Curve/|   |-[62] MUDS (Mud Source)',
#  'Curve/|   |-[63] MUDD KG/M3 (Mud Density)',
#  'Curve/|   |-[64] MUDV S (Mud Viscosity (Funnel))',
#  'Curve/|   |-[65] FL CC (Fluid Loss)',
#  'Curve/|   |-[66] PH (PH)',
#  'Curve/|   |-[67] RM OHMM (Resistivity of Mud)',
#  'Curve/|   |-[68] RMT DEGC (Temperature of Mud)',
#  'Curve/|   |-[69] RMF OHMM (Rest. of Mud Filtrate)',
#  'Curve/|   |-[70] RMFT DEGC (Temp. of Mud Filtrate)',
#  'Curve/|   |-[71] RMC OHMM (Rest. of Mud Cake)',
#  'Curve/|   |-[72] RMCT DEGC (Temp. of Mud Cake)',
#  'Curve/|   |-[73] TMAX DEGC (Max. Recorded Temp.)',
#  'Curve/|   |-[74] TIMC (Date/Time Circulation Stopped)',
#  'Curve/|   |-[75] TIML (Date/Time Logger Tagged Bottom)',
#  'Curve/|   |-[76] UNIT (Logging Unit Number)',
#  'Curve/|   |-[77] BASE (Home Base of Logging Unit)',
#  'Curve/|   |-[78] ENG (Recording Engineer)',
#  'Curve/|   |-[79] WIT (Witnessed By)',
#  'Curve/|- data:',
#  'Curve/|   |-[0] DEPT, M: DEPTH',
#  'Curve/|   |-[1] DT, US/M (123 456 789): SONIC TRANSIT TIME',
#  "Curve/|   |-[2] DPHI, V/V (123 456 789): DENSITY POROSITY | ('MDEN[1]', 'MDEN[2]')",
#  "Curve/|   |-[3] NPHI, V/V (123 456 789): NEUTRON POROSITY | ('MATR[1]', 'MATR[2]')",
#  'Curve/|   |-[4] YME, PA (123 456 789): YOUNGS MODULES',
#  'Curve/|   |-[5] CDES (123 456 789): CORE DESCRIPTION',
#  'Curve/|   |-[6] NMR[1], mv (123 456 789): NMR Echo Array',
#  'Curve/|   |-[7] NMR[2], mv (123 456 789): NMR Echo Array',
#  'Curve/|   |-[8] NMR[3], mv (123 456 789): NMR Echo Array',
#  'Curve/|   |-[9] NMR[4], mv (123 456 789): NMR Echo Array',
#  'Curve/|   |-[10] NMR[5], mv (123 456 789): NMR Echo Array',
#  '|- Drilling_Data',
#  'Drilling_Data/|- parameters:',
#  'Drilling_Data/|   |-[0] RIG: BIG RIG (Drilling Rig name)',
#  'Drilling_Data/|   |-[1] CONTR: DLR DRILLING (Contractor)',
#  'Drilling_Data/|- data:',
#  'Drilling_Data/|   |-[0] DEPT, ft: Depth',
#  'Drilling_Data/|   |-[1] DIST, ft: Cumulative increment of drilling.',
#  'Drilling_Data/|   |-[2] HRS, hour: Hours of drilling',
#  'Drilling_Data/|   |-[3] ROP, ft/hr: Rate of Penetration',
#  'Drilling_Data/|   |-[4] WOB, klb: Weight on bit',
#  'Drilling_Data/|   |-[5] RPM, RPM: Rotations per minute',
#  'Drilling_Data/|   |-[6] TQ, AMPS: Torque on bit in amps',
#  'Drilling_Data/|   |-[7] PUMP, psi: Mud pump pressure',
#  'Drilling_Data/|   |-[8] TSPM, SPM: Total strokes per minute',
#  'Drilling_Data/|   |-[9] GPM, gal/min: Gallons per minute',
#  'Drilling_Data/|   |-[10] ECD, ppg: Effective circulation density',
#  'Drilling_Data/|   |-[11] TBR: Total barrels returned',
#  '|- Core_Data[1]',
#  'Core_Data[1]/|- parameters:',
#  'Core_Data[1]/|   |-[0] C_SRS (Core Source)',
#  'Core_Data[1]/|   |-[1] C_TY (Core Type)',
#  'Core_Data[1]/|   |-[2] C_DT (Recovery Date (Date Core Cut))',
#  'Core_Data[1]/|   |-[3] C_TP M (Core Top Depth)',
#  'Core_Data[1]/|   |-[4] C_BS M (Core Base Depth)',
#  'Core_Data[1]/|   |-[5] C_RC M (Recovered Amount (Length))',
#  'Core_Data[1]/|   |-[6] C_FM (Primary Formation Cored)',
#  'Core_Data[1]/|   |-[7] C_DI mm (Core Diameter)',
#  'Core_Data[1]/|   |-[8] C_AC (Analyzing Company)',
#  'Core_Data[1]/|   |-[9] C_AD (Analysis Date)',
#  'Core_Data[1]/|- data:',
#  'Core_Data[1]/|   |-[0] CORT, M: Core top depth',
#  'Core_Data[1]/|   |-[1] CORB, M: Core Bottom Depth',
#  'Core_Data[1]/|   |-[2] PERM, md: Core permeability',
#  'Core_Data[1]/|   |-[3] CPOR, %: Core porosity',
#  'Core_Data[1]/|   |-[4] OIL, %: Core Oil saturation',
#  'Core_Data[1]/|   |-[5] WTR, %: Core water saturation',
#  'Core_Data[1]/|   |-[6] Oilvol, %: Core oil volume',
#  'Core_Data[1]/|   |-[7] GAS, %: Core gas saturation',
#  'Core_Data[1]/|   |-[8] WTR, %: Core water volume',
#  'Core_Data[1]/|   |-[9] CDES: Core description',
#  '|- Core_Data[2]',
#  'Core_Data[2]/|- parameters:',
#  'Core_Data[2]/|   |-[0] C_SRS (Core Source)',
#  'Core_Data[2]/|   |-[1] C_TY (Core Type)',
#  'Core_Data[2]/|   |-[2] C_DT (Recovery Date (Date Core Cut))',
#  'Core_Data[2]/|   |-[3] C_TP M (Core Top Depth)',
#  'Core_Data[2]/|   |-[4] C_BS M (Core Base Depth)',
#  'Core_Data[2]/|   |-[5] C_RC M (Recovered Amount (Length))',
#  'Core_Data[2]/|   |-[6] C_FM (Primary Formation Cored)',
#  'Core_Data[2]/|   |-[7] C_DI mm (Core Diameter)',
#  'Core_Data[2]/|   |-[8] C_AC (Analyzing Company)',
#  'Core_Data[2]/|   |-[9] C_AD (Analysis Date)',
#  'Core_Data[2]/|- data:',
#  'Core_Data[2]/|   |-[0] CORT, M: Core top depth',
#  'Core_Data[2]/|   |-[1] CORB, M: Core Bottom Depth',
#  'Core_Data[2]/|   |-[2] PERM, md: Core permeability',
#  'Core_Data[2]/|   |-[3] CPOR, PU: Core porosity',
#  '|- Inclinometry_Data',
#  'Inclinometry_Data/|- parameters:',
#  'Inclinometry_Data/|   |-[0] I_DT (SURVEY_DATE)',
#  'Inclinometry_Data/|   |-[1] I_CO (Recording Company)',
#  'Inclinometry_Data/|   |-[2] I_RF M (Depth Datum Elevation (from MSL))',
#  'Inclinometry_Data/|   |-[3] I_AT (Azimuth North Type (e.g. Grid/ True))',
#  'Inclinometry_Data/|   |-[4] I_DC DEG (Magnetic Declination (if I_AT not magnetic))',
#  'Inclinometry_Data/|   |-[5] I_KO M (Kickoff Depth (M.D. of kickoff point))',
#  'Inclinometry_Data/|   |-[6] I_GD (Geodetic datum)',
#  'Inclinometry_Data/|   |-[7] I_ONS (N/S Offset of well ref point to top hole)',
#  'Inclinometry_Data/|   |-[8] I_OEW Unit (E/W Offset of well ref point to top hole)',
#  'Inclinometry_Data/|   |-[9] I_CP (COMPUTE_METHOD (e.g. Radius of Curvature))',
#  'Inclinometry_Data/|   |-[10] I_CS (COORDINATE_SYSTEM_NAME eg UTM18N)',
#  'Inclinometry_Data/|   |-[11] TIEMD M (Tie Point Measured depth)',
#  'Inclinometry_Data/|   |-[12] TIETVD M (Tie Point True Vertical depth)',
#  'Inclinometry_Data/|   |-[13] TIEDEV M (Tie Point Deviation)',
#  'Inclinometry_Data/|   |-[14] TIEAZM M (Tie Point Azimuth)',
#  'Inclinometry_Data/|   |-[15] TIENSDR M (Tie Point North South drift)',
#  'Inclinometry_Data/|   |-[16] TIEEWDR M (Tie Point East West drift)',
#  'Inclinometry_Data/|- data:',
#  'Inclinometry_Data/|   |-[0] MD, M: Measured Depth',
#  'Inclinometry_Data/|   |-[1] TVD, M: True Vertical Depth',
#  'Inclinometry_Data/|   |-[2] AZIM, DEG: Borehole Azimuth',
#  'Inclinometry_Data/|   |-[3] DEVI, DEG: Borehole Deviation',
#  'Inclinometry_Data/|   |-[4] RB, DEG: Relative Bearing',
#  '|- Test_Data',
#  'Test_Data/|- parameters:',
#  'Test_Data/|   |-[0] TESTT: DST (Test Type)',
#  'Test_Data/|- data:',
#  'Test_Data/|   |-[0] TSTN: TEST Number',
#  'Test_Data/|   |-[1] TSTT, M: TEST Top Depth',
#  'Test_Data/|   |-[2] TSTB, M: TEST Bottom Depth',
#  'Test_Data/|   |-[3] DDES: TEST Recovery Description',
#  'Test_Data/|   |-[4] ISIP, KPAA: Initial Shut in pressure',
#  'Test_Data/|   |-[5] FSIP, KPAA: Final Shut in pressure',
#  'Test_Data/|   |-[6] RATE, BOPD: Production Rate',
#  'Test_Data/|   |-[7] BLOWD: BLOW DESCRIPTION',
#  '|- Tops_Data',
#  'Tops_Data/|- parameters:',
#  'Tops_Data/|   |-[0] TOPS: Prognosis (Formation Source)',
#  'Tops_Data/|   |-[1] TOPDR: Subsea (Tops Depth Reference)',
#  'Tops_Data/|- data:',
#  'Tops_Data/|   |-[0] TOPT, M: Formation Top Depth',
#  'Tops_Data/|   |-[1] TOPB, M: Formation Base Depth',
#  'Tops_Data/|   |-[2] TOPN: Formation Top Name',
#  '|- Perforation_Data',
#  'Perforation_Data/|- parameters:',
#  'Perforation_Data/|   |-[0] PERFTYPE: 55 gr BIG HOLE (Charge Type)',
#  'Perforation_Data/|- data:',
#  'Perforation_Data/|   |-[0] PERFT, M: Perforation Top Depth',
#  'Perforation_Data/|   |-[1] PERFB, M: Perforation Bottom Depth',
#  'Perforation_Data/|   |-[2] PERFD, SHOTS/M: Shot density per meter']
# Out[3:2]:
# ['Well/STRT',
#  'Well/STOP',
#  'Well/STEP',
#  'Well/NULL',
#  'Well/COMP',
#  'Well/WELL',
#  'Well/FLD',
#  'Well/LOC',
#  'Well/SRVC',
#  'Well/DATE',
#  'Well/CTRY',
#  'Well/PROV',
#  'Well/UWI',
#  'Well/LIC',
#  'Well/LATI',
#  'Well/LONG',
#  'Well/GDAT',
#  '|- Curve',
#  'Curve/|- parameters:',
#  'Curve/|   |-[0] PDAT: GL (Permanent Data)',
#  'Curve/|   |-[1] APD: 4.2 M (Above Permanent Data)',
#  'Curve/|   |-[2] DREF: KB (Depth Reference (KB,DF,CB))',
#  'Curve/|   |-[3] EREF: 234.5 M (Elevation of Depth Reference)',
#  'Curve/|   |-[4] RUN: 1 (Run Number)',
#  'Curve/|   |-[5] RUNS: 2 (# of Runs for this well.)',
#  'Curve/|   |-[6] RUN[1]: 2 (Number of the indexed RUN)',
#  'Curve/|   |-[7] RUN[2]: 3 (Number of the indexed RUN)',
#  'Curve/|   |-[8] RUN_Depth[1]: (0.0, 1500.0) M (Run 1 Depth Interval)',
#  'Curve/|   |-[9] RUN_Depth[2]: (1500.0, 2513.0) M (Run 2 Depth Interval)',
#  'Curve/|   |-[10] NMAT_Depth[1]: (523.0, 1500.0) M (Neutron Matrix Depth interval)',
#  'Curve/|   |-[11] NMAT_Depth[2]: (1500.0, 2500.0) M (Neutron Matrix Depth interval)',
#  'Curve/|   |-[12] DMAT_Depth[1]: (523.0, 1510.0) M (Density Matrix Depth interval)',
#  'Curve/|   |-[13] DMAT_Depth[2]: (1510.0, 2510.0) M (Density Matrix Depth interval)',
#  'Curve/|   |-[14] MATR[1]: SAND (Neutron Porosity Matrix)',
#  'Curve/|   |-[15] MATR[2]: LIME (Neutron Porosity Matrix)',
#  'Curve/|   |-[16] MDEN[1]: 2650 KG/M3 (Neutron Porosity Matrix)',
#  'Curve/|   |-[17] MDEN[2]: 2710 KG/M3 (Neutron Porosity Matrix)',
#  'Curve/|   |-[18] FR_LR[1]: 500,100 M',
#  'Curve/|   |-[19] FR_LR[2]: 523,100 M',
#  'Curve/|   |-[20] FR_LR[3]: 520,100 M',
#  'Curve/|   |-[21] FR_LR[4]: 500,100 M',
#  'Curve/|   |-[22] FR_LR[5] M',
#  'Curve/|   |-[23] FR_LR[6]: 510,100 M',
#  'Curve/|   |-[24] FR_LR[7]: 510,100 M',
#  'Curve/|   |-[25] FR_LR[8]: 510,100 M',
#  'Curve/|   |-[26] FR_LR[9]: 510,100 M',
#  'Curve/|   |-[27] FR_LR[10]: 510,100 M',
#  'Curve/|   |-[28] TDL M (Total Depth Logger)',
#  'Curve/|   |-[29] TDD M (Total Depth Driller)',
#  'Curve/|   |-[30] CSGL M (Casing Bottom Logger)',
#  'Curve/|   |-[31] CSGD M (Casing Bottom Driller)',
#  'Curve/|   |-[32] CSGS MM (Casing Size)',
#  'Curve/|   |-[33] CSGW KG/M (Casing Weight)',
#  'Curve/|   |-[34] BS MM (Bit Size)',
#  'Curve/|   |-[35] MUD (Mud type)',
#  'Curve/|   |-[36] MUDS (Mud Source)',
#  'Curve/|   |-[37] MUDD KG/M3 (Mud Density)',
#  'Curve/|   |-[38] MUDV S (Mud Viscosity (Funnel))',
#  'Curve/|   |-[39] FL CC (Fluid Loss)',
#  'Curve/|   |-[40] PH (PH)',
#  'Curve/|   |-[41] RM OHMM (Resistivity of Mud)',
#  'Curve/|   |-[42] RMT DEGC (Temperature of Mud)',
#  'Curve/|   |-[43] RMF OHMM (Rest. of Mud Filtrate)',
#  'Curve/|   |-[44] RMFT DEGC (Temp. of Mud Filtrate)',
#  'Curve/|   |-[45] RMC OHMM (Rest. of Mud Cake)',
#  'Curve/|   |-[46] RMCT DEGC (Temp. of Mud Cake)',
#  'Curve/|   |-[47] TMAX DEGC (Max. Recorded Temp.)',
#  'Curve/|   |-[48] TIMC (Date/Time Circulation Stopped)',
#  'Curve/|   |-[49] TIML (Date/Time Logger Tagged Bottom)',
#  'Curve/|   |-[50] UNIT (Logging Unit Number)',
#  'Curve/|   |-[51] BASE (Home Base of Logging Unit)',
#  'Curve/|   |-[52] ENG (Recording Engineer)',
#  'Curve/|   |-[53] WIT (Witnessed By)',
#  'Curve/|   |-[54] TDL M (Total Depth Logger)',
#  'Curve/|   |-[55] TDD M (Total Depth Driller)',
#  'Curve/|   |-[56] CSGL M (Casing Bottom Logger)',
#  'Curve/|   |-[57] CSGD M (Casing Bottom Driller)',
#  'Curve/|   |-[58] CSGS MM (Casing Size)',
#  'Curve/|   |-[59] CSGW KG/M (Casing Weight)',
#  'Curve/|   |-[60] BS MM (Bit Size)',
#  'Curve/|   |-[61] MUD (Mud type)',
#  'Curve/|   |-[62] MUDS (Mud Source)',
#  'Curve/|   |-[63] MUDD KG/M3 (Mud Density)',
#  'Curve/|   |-[64] MUDV S (Mud Viscosity (Funnel))',
#  'Curve/|   |-[65] FL CC (Fluid Loss)',
#  'Curve/|   |-[66] PH (PH)',
#  'Curve/|   |-[67] RM OHMM (Resistivity of Mud)',
#  'Curve/|   |-[68] RMT DEGC (Temperature of Mud)',
#  'Curve/|   |-[69] RMF OHMM (Rest. of Mud Filtrate)',
#  'Curve/|   |-[70] RMFT DEGC (Temp. of Mud Filtrate)',
#  'Curve/|   |-[71] RMC OHMM (Rest. of Mud Cake)',
#  'Curve/|   |-[72] RMCT DEGC (Temp. of Mud Cake)',
#  'Curve/|   |-[73] TMAX DEGC (Max. Recorded Temp.)',
#  'Curve/|   |-[74] TIMC (Date/Time Circulation Stopped)',
#  'Curve/|   |-[75] TIML (Date/Time Logger Tagged Bottom)',
#  'Curve/|   |-[76] UNIT (Logging Unit Number)',
#  'Curve/|   |-[77] BASE (Home Base of Logging Unit)',
#  'Curve/|   |-[78] ENG (Recording Engineer)',
#  'Curve/|   |-[79] WIT (Witnessed By)',
#  'Curve/|- data:',
#  'Curve/|   |-[0] DEPT, M: DEPTH',
#  'Curve/|   |-[1] DT, US/M (123 456 789): SONIC TRANSIT TIME',
#  "Curve/|   |-[2] DPHI, V/V (123 456 789): DENSITY POROSITY | ('MDEN[1]', 'MDEN[2]')",
#  "Curve/|   |-[3] NPHI, V/V (123 456 789): NEUTRON POROSITY | ('MATR[1]', 'MATR[2]')",
#  'Curve/|   |-[4] YME, PA (123 456 789): YOUNGS MODULES',
#  'Curve/|   |-[5] CDES (123 456 789): CORE DESCRIPTION',
#  'Curve/|   |-[6] NMR[1], mv (123 456 789): NMR Echo Array',
#  'Curve/|   |-[7] NMR[2], mv (123 456 789): NMR Echo Array',
#  'Curve/|   |-[8] NMR[3], mv (123 456 789): NMR Echo Array',
#  'Curve/|   |-[9] NMR[4], mv (123 456 789): NMR Echo Array',
#  'Curve/|   |-[10] NMR[5], mv (123 456 789): NMR Echo Array',
#  '|- Drilling_Data',
#  'Drilling_Data/|- parameters:',
#  'Drilling_Data/|   |-[0] RIG: BIG RIG (Drilling Rig name)',
#  'Drilling_Data/|   |-[1] CONTR: DLR DRILLING (Contractor)',
#  'Drilling_Data/|- data:',
#  'Drilling_Data/|   |-[0] DEPT, ft: Depth',
#  'Drilling_Data/|   |-[1] DIST, ft: Cumulative increment of drilling.',
#  'Drilling_Data/|   |-[2] HRS, hour: Hours of drilling',
#  'Drilling_Data/|   |-[3] ROP, ft/hr: Rate of Penetration',
#  'Drilling_Data/|   |-[4] WOB, klb: Weight on bit',
#  'Drilling_Data/|   |-[5] RPM, RPM: Rotations per minute',
#  'Drilling_Data/|   |-[6] TQ, AMPS: Torque on bit in amps',
#  'Drilling_Data/|   |-[7] PUMP, psi: Mud pump pressure',
#  'Drilling_Data/|   |-[8] TSPM, SPM: Total strokes per minute',
#  'Drilling_Data/|   |-[9] GPM, gal/min: Gallons per minute',
#  'Drilling_Data/|   |-[10] ECD, ppg: Effective circulation density',
#  'Drilling_Data/|   |-[11] TBR: Total barrels returned',
#  '|- Core_Data[1]',
#  'Core_Data[1]/|- parameters:',
#  'Core_Data[1]/|   |-[0] C_SRS (Core Source)',
#  'Core_Data[1]/|   |-[1] C_TY (Core Type)',
#  'Core_Data[1]/|   |-[2] C_DT (Recovery Date (Date Core Cut))',
#  'Core_Data[1]/|   |-[3] C_TP M (Core Top Depth)',
#  'Core_Data[1]/|   |-[4] C_BS M (Core Base Depth)',
#  'Core_Data[1]/|   |-[5] C_RC M (Recovered Amount (Length))',
#  'Core_Data[1]/|   |-[6] C_FM (Primary Formation Cored)',
#  'Core_Data[1]/|   |-[7] C_DI mm (Core Diameter)',
#  'Core_Data[1]/|   |-[8] C_AC (Analyzing Company)',
#  'Core_Data[1]/|   |-[9] C_AD (Analysis Date)',
#  'Core_Data[1]/|- data:',
#  'Core_Data[1]/|   |-[0] CORT, M: Core top depth',
#  'Core_Data[1]/|   |-[1] CORB, M: Core Bottom Depth',
#  'Core_Data[1]/|   |-[2] PERM, md: Core permeability',
#  'Core_Data[1]/|   |-[3] CPOR, %: Core porosity',
#  'Core_Data[1]/|   |-[4] OIL, %: Core Oil saturation',
#  'Core_Data[1]/|   |-[5] WTR, %: Core water saturation',
#  'Core_Data[1]/|   |-[6] Oilvol, %: Core oil volume',
#  'Core_Data[1]/|   |-[7] GAS, %: Core gas saturation',
#  'Core_Data[1]/|   |-[8] WTR, %: Core water volume',
#  'Core_Data[1]/|   |-[9] CDES: Core description',
#  '|- Core_Data[2]',
#  'Core_Data[2]/|- parameters:',
#  'Core_Data[2]/|   |-[0] C_SRS (Core Source)',
#  'Core_Data[2]/|   |-[1] C_TY (Core Type)',
#  'Core_Data[2]/|   |-[2] C_DT (Recovery Date (Date Core Cut))',
#  'Core_Data[2]/|   |-[3] C_TP M (Core Top Depth)',
#  'Core_Data[2]/|   |-[4] C_BS M (Core Base Depth)',
#  'Core_Data[2]/|   |-[5] C_RC M (Recovered Amount (Length))',
#  'Core_Data[2]/|   |-[6] C_FM (Primary Formation Cored)',
#  'Core_Data[2]/|   |-[7] C_DI mm (Core Diameter)',
#  'Core_Data[2]/|   |-[8] C_AC (Analyzing Company)',
#  'Core_Data[2]/|   |-[9] C_AD (Analysis Date)',
#  'Core_Data[2]/|- data:',
#  'Core_Data[2]/|   |-[0] CORT, M: Core top depth',
#  'Core_Data[2]/|   |-[1] CORB, M: Core Bottom Depth',
#  'Core_Data[2]/|   |-[2] PERM, md: Core permeability',
#  'Core_Data[2]/|   |-[3] CPOR, PU: Core porosity',
#  '|- Inclinometry_Data',
#  'Inclinometry_Data/|- parameters:',
#  'Inclinometry_Data/|   |-[0] I_DT (SURVEY_DATE)',
#  'Inclinometry_Data/|   |-[1] I_CO (Recording Company)',
#  'Inclinometry_Data/|   |-[2] I_RF M (Depth Datum Elevation (from MSL))',
#  'Inclinometry_Data/|   |-[3] I_AT (Azimuth North Type (e.g. Grid/ True))',
#  'Inclinometry_Data/|   |-[4] I_DC DEG (Magnetic Declination (if I_AT not magnetic))',
#  'Inclinometry_Data/|   |-[5] I_KO M (Kickoff Depth (M.D. of kickoff point))',
#  'Inclinometry_Data/|   |-[6] I_GD (Geodetic datum)',
#  'Inclinometry_Data/|   |-[7] I_ONS (N/S Offset of well ref point to top hole)',
#  'Inclinometry_Data/|   |-[8] I_OEW Unit (E/W Offset of well ref point to top hole)',
#  'Inclinometry_Data/|   |-[9] I_CP (COMPUTE_METHOD (e.g. Radius of Curvature))',
#  'Inclinometry_Data/|   |-[10] I_CS (COORDINATE_SYSTEM_NAME eg UTM18N)',
#  'Inclinometry_Data/|   |-[11] TIEMD M (Tie Point Measured depth)',
#  'Inclinometry_Data/|   |-[12] TIETVD M (Tie Point True Vertical depth)',
#  'Inclinometry_Data/|   |-[13] TIEDEV M (Tie Point Deviation)',
#  'Inclinometry_Data/|   |-[14] TIEAZM M (Tie Point Azimuth)',
#  'Inclinometry_Data/|   |-[15] TIENSDR M (Tie Point North South drift)',
#  'Inclinometry_Data/|   |-[16] TIEEWDR M (Tie Point East West drift)',
#  'Inclinometry_Data/|- data:',
#  'Inclinometry_Data/|   |-[0] MD, M: Measured Depth',
#  'Inclinometry_Data/|   |-[1] TVD, M: True Vertical Depth',
#  'Inclinometry_Data/|   |-[2] AZIM, DEG: Borehole Azimuth',
#  'Inclinometry_Data/|   |-[3] DEVI, DEG: Borehole Deviation',
#  'Inclinometry_Data/|   |-[4] RB, DEG: Relative Bearing',
#  '|- Test_Data',
#  'Test_Data/|- parameters:',
#  'Test_Data/|   |-[0] TESTT: DST (Test Type)',
#  'Test_Data/|- data:',
#  'Test_Data/|   |-[0] TSTN: TEST Number',
#  'Test_Data/|   |-[1] TSTT, M: TEST Top Depth',
#  'Test_Data/|   |-[2] TSTB, M: TEST Bottom Depth',
#  'Test_Data/|   |-[3] DDES: TEST Recovery Description',
#  'Test_Data/|   |-[4] ISIP, KPAA: Initial Shut in pressure',
#  'Test_Data/|   |-[5] FSIP, KPAA: Final Shut in pressure',
#  'Test_Data/|   |-[6] RATE, BOPD: Production Rate',
#  'Test_Data/|   |-[7] BLOWD: BLOW DESCRIPTION',
#  '|- Tops_Data',
#  'Tops_Data/|- parameters:',
#  'Tops_Data/|   |-[0] TOPS: Prognosis (Formation Source)',
#  'Tops_Data/|   |-[1] TOPDR: Subsea (Tops Depth Reference)',
#  'Tops_Data/|- data:',
#  'Tops_Data/|   |-[0] TOPT, M: Formation Top Depth',
#  'Tops_Data/|   |-[1] TOPB, M: Formation Base Depth',
#  'Tops_Data/|   |-[2] TOPN: Formation Top Name',
#  '|- Perforation_Data',
#  'Perforation_Data/|- parameters:',
#  'Perforation_Data/|   |-[0] PERFTYPE: 55 gr BIG HOLE (Charge Type)',
#  'Perforation_Data/|- data:',
#  'Perforation_Data/|   |-[0] PERFT, M: Perforation Top Depth',
#  'Perforation_Data/|   |-[1] PERFB, M: Perforation Bottom Depth',
#  'Perforation_Data/|   |-[2] PERFD, SHOTS/M: Shot density per meter']
# Out[1:2]:
# ['Well/STRT',
#  'Well/STOP',
#  'Well/STEP',
#  'Well/NULL',
#  'Well/COMP',
#  'Well/WELL',
#  'Well/FLD',
#  'Well/LOC',
#  'Well/SRVC',
#  'Well/DATE',
#  'Well/CTRY',
#  'Well/PROV',
#  'Well/UWI',
#  'Well/LIC',
#  'Well/LATI',
#  'Well/LONG',
#  'Well/GDAT',
#  '|- Curve',
#  'Curve/|- parameters:',
#  'Curve/|   |-[0] PDAT: GL (Permanent Data)',
#  'Curve/|   |-[1] APD: 4.2 M (Above Permanent Data)',
#  'Curve/|   |-[2] DREF: KB (Depth Reference (KB,DF,CB))',
#  'Curve/|   |-[3] EREF: 234.5 M (Elevation of Depth Reference)',
#  'Curve/|   |-[4] RUN: 1 (Run Number)',
#  'Curve/|   |-[5] RUNS: 2 (# of Runs for this well.)',
#  'Curve/|   |-[6] RUN[1]: 2 (Number of the indexed RUN)',
#  'Curve/|   |-[7] RUN[2]: 3 (Number of the indexed RUN)',
#  'Curve/|   |-[8] RUN_Depth[1]: (0.0, 1500.0) M (Run 1 Depth Interval)',
#  'Curve/|   |-[9] RUN_Depth[2]: (1500.0, 2513.0) M (Run 2 Depth Interval)',
#  'Curve/|   |-[10] NMAT_Depth[1]: (523.0, 1500.0) M (Neutron Matrix Depth interval)',
#  'Curve/|   |-[11] NMAT_Depth[2]: (1500.0, 2500.0) M (Neutron Matrix Depth interval)',
#  'Curve/|   |-[12] DMAT_Depth[1]: (523.0, 1510.0) M (Density Matrix Depth interval)',
#  'Curve/|   |-[13] DMAT_Depth[2]: (1510.0, 2510.0) M (Density Matrix Depth interval)',
#  'Curve/|   |-[14] MATR[1]: SAND (Neutron Porosity Matrix)',
#  'Curve/|   |-[15] MATR[2]: LIME (Neutron Porosity Matrix)',
#  'Curve/|   |-[16] MDEN[1]: 2650 KG/M3 (Neutron Porosity Matrix)',
#  'Curve/|   |-[17] MDEN[2]: 2710 KG/M3 (Neutron Porosity Matrix)',
#  'Curve/|   |-[18] FR_LR[1]: 500,100 M',
#  'Curve/|   |-[19] FR_LR[2]: 523,100 M',
#  'Curve/|   |-[20] FR_LR[3]: 520,100 M',
#  'Curve/|   |-[21] FR_LR[4]: 500,100 M',
#  'Curve/|   |-[22] FR_LR[5] M',
#  'Curve/|   |-[23] FR_LR[6]: 510,100 M',
#  'Curve/|   |-[24] FR_LR[7]: 510,100 M',
#  'Curve/|   |-[25] FR_LR[8]: 510,100 M',
#  'Curve/|   |-[26] FR_LR[9]: 510,100 M',
#  'Curve/|   |-[27] FR_LR[10]: 510,100 M',
#  'Curve/|   |-[28] TDL M (Total Depth Logger)',
#  'Curve/|   |-[29] TDD M (Total Depth Driller)',
#  'Curve/|   |-[30] CSGL M (Casing Bottom Logger)',
#  'Curve/|   |-[31] CSGD M (Casing Bottom Driller)',
#  'Curve/|   |-[32] CSGS MM (Casing Size)',
#  'Curve/|   |-[33] CSGW KG/M (Casing Weight)',
#  'Curve/|   |-[34] BS MM (Bit Size)',
#  'Curve/|   |-[35] MUD (Mud type)',
#  'Curve/|   |-[36] MUDS (Mud Source)',
#  'Curve/|   |-[37] MUDD KG/M3 (Mud Density)',
#  'Curve/|   |-[38] MUDV S (Mud Viscosity (Funnel))',
#  'Curve/|   |-[39] FL CC (Fluid Loss)',
#  'Curve/|   |-[40] PH (PH)',
#  'Curve/|   |-[41] RM OHMM (Resistivity of Mud)',
#  'Curve/|   |-[42] RMT DEGC (Temperature of Mud)',
#  'Curve/|   |-[43] RMF OHMM (Rest. of Mud Filtrate)',
#  'Curve/|   |-[44] RMFT DEGC (Temp. of Mud Filtrate)',
#  'Curve/|   |-[45] RMC OHMM (Rest. of Mud Cake)',
#  'Curve/|   |-[46] RMCT DEGC (Temp. of Mud Cake)',
#  'Curve/|   |-[47] TMAX DEGC (Max. Recorded Temp.)',
#  'Curve/|   |-[48] TIMC (Date/Time Circulation Stopped)',
#  'Curve/|   |-[49] TIML (Date/Time Logger Tagged Bottom)',
#  'Curve/|   |-[50] UNIT (Logging Unit Number)',
#  'Curve/|   |-[51] BASE (Home Base of Logging Unit)',
#  'Curve/|   |-[52] ENG (Recording Engineer)',
#  'Curve/|   |-[53] WIT (Witnessed By)',
#  'Curve/|   |-[54] TDL M (Total Depth Logger)',
#  'Curve/|   |-[55] TDD M (Total Depth Driller)',
#  'Curve/|   |-[56] CSGL M (Casing Bottom Logger)',
#  'Curve/|   |-[57] CSGD M (Casing Bottom Driller)',
#  'Curve/|   |-[58] CSGS MM (Casing Size)',
#  'Curve/|   |-[59] CSGW KG/M (Casing Weight)',
#  'Curve/|   |-[60] BS MM (Bit Size)',
#  'Curve/|   |-[61] MUD (Mud type)',
#  'Curve/|   |-[62] MUDS (Mud Source)',
#  'Curve/|   |-[63] MUDD KG/M3 (Mud Density)',
#  'Curve/|   |-[64] MUDV S (Mud Viscosity (Funnel))',
#  'Curve/|   |-[65] FL CC (Fluid Loss)',
#  'Curve/|   |-[66] PH (PH)',
#  'Curve/|   |-[67] RM OHMM (Resistivity of Mud)',
#  'Curve/|   |-[68] RMT DEGC (Temperature of Mud)',
#  'Curve/|   |-[69] RMF OHMM (Rest. of Mud Filtrate)',
#  'Curve/|   |-[70] RMFT DEGC (Temp. of Mud Filtrate)',
#  'Curve/|   |-[71] RMC OHMM (Rest. of Mud Cake)',
#  'Curve/|   |-[72] RMCT DEGC (Temp. of Mud Cake)',
#  'Curve/|   |-[73] TMAX DEGC (Max. Recorded Temp.)',
#  'Curve/|   |-[74] TIMC (Date/Time Circulation Stopped)',
#  'Curve/|   |-[75] TIML (Date/Time Logger Tagged Bottom)',
#  'Curve/|   |-[76] UNIT (Logging Unit Number)',
#  'Curve/|   |-[77] BASE (Home Base of Logging Unit)',
#  'Curve/|   |-[78] ENG (Recording Engineer)',
#  'Curve/|   |-[79] WIT (Witnessed By)',
#  'Curve/|- data:',
#  'Curve/|   |-[0] DEPT, M: DEPTH',
#  'Curve/|   |-[1] DT, US/M (123 456 789): SONIC TRANSIT TIME',
#  "Curve/|   |-[2] DPHI, V/V (123 456 789): DENSITY POROSITY | ('MDEN[1]', 'MDEN[2]')",
#  "Curve/|   |-[3] NPHI, V/V (123 456 789): NEUTRON POROSITY | ('MATR[1]', 'MATR[2]')",
#  'Curve/|   |-[4] YME, PA (123 456 789): YOUNGS MODULES',
#  'Curve/|   |-[5] CDES (123 456 789): CORE DESCRIPTION',
#  'Curve/|   |-[6] NMR[1], mv (123 456 789): NMR Echo Array',
#  'Curve/|   |-[7] NMR[2], mv (123 456 789): NMR Echo Array',
#  'Curve/|   |-[8] NMR[3], mv (123 456 789): NMR Echo Array',
#  'Curve/|   |-[9] NMR[4], mv (123 456 789): NMR Echo Array',
#  'Curve/|   |-[10] NMR[5], mv (123 456 789): NMR Echo Array',
#  '|- Drilling_Data',
#  'Drilling_Data/|- parameters:',
#  'Drilling_Data/|   |-[0] RIG: BIG RIG (Drilling Rig name)',
#  'Drilling_Data/|   |-[1] CONTR: DLR DRILLING (Contractor)',
#  'Drilling_Data/|- data:',
#  'Drilling_Data/|   |-[0] DEPT, ft: Depth',
#  'Drilling_Data/|   |-[1] DIST, ft: Cumulative increment of drilling.',
#  'Drilling_Data/|   |-[2] HRS, hour: Hours of drilling',
#  'Drilling_Data/|   |-[3] ROP, ft/hr: Rate of Penetration',
#  'Drilling_Data/|   |-[4] WOB, klb: Weight on bit',
#  'Drilling_Data/|   |-[5] RPM, RPM: Rotations per minute',
#  'Drilling_Data/|   |-[6] TQ, AMPS: Torque on bit in amps',
#  'Drilling_Data/|   |-[7] PUMP, psi: Mud pump pressure',
#  'Drilling_Data/|   |-[8] TSPM, SPM: Total strokes per minute',
#  'Drilling_Data/|   |-[9] GPM, gal/min: Gallons per minute',
#  'Drilling_Data/|   |-[10] ECD, ppg: Effective circulation density',
#  'Drilling_Data/|   |-[11] TBR: Total barrels returned',
#  '|- Core_Data[1]',
#  'Core_Data[1]/|- parameters:',
#  'Core_Data[1]/|   |-[0] C_SRS (Core Source)',
#  'Core_Data[1]/|   |-[1] C_TY (Core Type)',
#  'Core_Data[1]/|   |-[2] C_DT (Recovery Date (Date Core Cut))',
#  'Core_Data[1]/|   |-[3] C_TP M (Core Top Depth)',
#  'Core_Data[1]/|   |-[4] C_BS M (Core Base Depth)',
#  'Core_Data[1]/|   |-[5] C_RC M (Recovered Amount (Length))',
#  'Core_Data[1]/|   |-[6] C_FM (Primary Formation Cored)',
#  'Core_Data[1]/|   |-[7] C_DI mm (Core Diameter)',
#  'Core_Data[1]/|   |-[8] C_AC (Analyzing Company)',
#  'Core_Data[1]/|   |-[9] C_AD (Analysis Date)',
#  'Core_Data[1]/|- data:',
#  'Core_Data[1]/|   |-[0] CORT, M: Core top depth',
#  'Core_Data[1]/|   |-[1] CORB, M: Core Bottom Depth',
#  'Core_Data[1]/|   |-[2] PERM, md: Core permeability',
#  'Core_Data[1]/|   |-[3] CPOR, %: Core porosity',
#  'Core_Data[1]/|   |-[4] OIL, %: Core Oil saturation',
#  'Core_Data[1]/|   |-[5] WTR, %: Core water saturation',
#  'Core_Data[1]/|   |-[6] Oilvol, %: Core oil volume',
#  'Core_Data[1]/|   |-[7] GAS, %: Core gas saturation',
#  'Core_Data[1]/|   |-[8] WTR, %: Core water volume',
#  'Core_Data[1]/|   |-[9] CDES: Core description',
#  '|- Core_Data[2]',
#  'Core_Data[2]/|- parameters:',
#  'Core_Data[2]/|   |-[0] C_SRS (Core Source)',
#  'Core_Data[2]/|   |-[1] C_TY (Core Type)',
#  'Core_Data[2]/|   |-[2] C_DT (Recovery Date (Date Core Cut))',
#  'Core_Data[2]/|   |-[3] C_TP M (Core Top Depth)',
#  'Core_Data[2]/|   |-[4] C_BS M (Core Base Depth)',
#  'Core_Data[2]/|   |-[5] C_RC M (Recovered Amount (Length))',
#  'Core_Data[2]/|   |-[6] C_FM (Primary Formation Cored)',
#  'Core_Data[2]/|   |-[7] C_DI mm (Core Diameter)',
#  'Core_Data[2]/|   |-[8] C_AC (Analyzing Company)',
#  'Core_Data[2]/|   |-[9] C_AD (Analysis Date)',
#  'Core_Data[2]/|- data:',
#  'Core_Data[2]/|   |-[0] CORT, M: Core top depth',
#  'Core_Data[2]/|   |-[1] CORB, M: Core Bottom Depth',
#  'Core_Data[2]/|   |-[2] PERM, md: Core permeability',
#  'Core_Data[2]/|   |-[3] CPOR, PU: Core porosity',
#  '|- Inclinometry_Data',
#  'Inclinometry_Data/|- parameters:',
#  'Inclinometry_Data/|   |-[0] I_DT (SURVEY_DATE)',
#  'Inclinometry_Data/|   |-[1] I_CO (Recording Company)',
#  'Inclinometry_Data/|   |-[2] I_RF M (Depth Datum Elevation (from MSL))',
#  'Inclinometry_Data/|   |-[3] I_AT (Azimuth North Type (e.g. Grid/ True))',
#  'Inclinometry_Data/|   |-[4] I_DC DEG (Magnetic Declination (if I_AT not magnetic))',
#  'Inclinometry_Data/|   |-[5] I_KO M (Kickoff Depth (M.D. of kickoff point))',
#  'Inclinometry_Data/|   |-[6] I_GD (Geodetic datum)',
#  'Inclinometry_Data/|   |-[7] I_ONS (N/S Offset of well ref point to top hole)',
#  'Inclinometry_Data/|   |-[8] I_OEW Unit (E/W Offset of well ref point to top hole)',
#  'Inclinometry_Data/|   |-[9] I_CP (COMPUTE_METHOD (e.g. Radius of Curvature))',
#  'Inclinometry_Data/|   |-[10] I_CS (COORDINATE_SYSTEM_NAME eg UTM18N)',
#  'Inclinometry_Data/|   |-[11] TIEMD M (Tie Point Measured depth)',
#  'Inclinometry_Data/|   |-[12] TIETVD M (Tie Point True Vertical depth)',
#  'Inclinometry_Data/|   |-[13] TIEDEV M (Tie Point Deviation)',
#  'Inclinometry_Data/|   |-[14] TIEAZM M (Tie Point Azimuth)',
#  'Inclinometry_Data/|   |-[15] TIENSDR M (Tie Point North South drift)',
#  'Inclinometry_Data/|   |-[16] TIEEWDR M (Tie Point East West drift)',
#  'Inclinometry_Data/|- data:',
#  'Inclinometry_Data/|   |-[0] MD, M: Measured Depth',
#  'Inclinometry_Data/|   |-[1] TVD, M: True Vertical Depth',
#  'Inclinometry_Data/|   |-[2] AZIM, DEG: Borehole Azimuth',
#  'Inclinometry_Data/|   |-[3] DEVI, DEG: Borehole Deviation',
#  'Inclinometry_Data/|   |-[4] RB, DEG: Relative Bearing',
#  '|- Test_Data',
#  'Test_Data/|- parameters:',
#  'Test_Data/|   |-[0] TESTT: DST (Test Type)',
#  'Test_Data/|- data:',
#  'Test_Data/|   |-[0] TSTN: TEST Number',
#  'Test_Data/|   |-[1] TSTT, M: TEST Top Depth',
#  'Test_Data/|   |-[2] TSTB, M: TEST Bottom Depth',
#  'Test_Data/|   |-[3] DDES: TEST Recovery Description',
#  'Test_Data/|   |-[4] ISIP, KPAA: Initial Shut in pressure',
#  'Test_Data/|   |-[5] FSIP, KPAA: Final Shut in pressure',
#  'Test_Data/|   |-[6] RATE, BOPD: Production Rate',
#  'Test_Data/|   |-[7] BLOWD: BLOW DESCRIPTION',
#  '|- Tops_Data',
#  'Tops_Data/|- parameters:',
#  'Tops_Data/|   |-[0] TOPS: Prognosis (Formation Source)',
#  'Tops_Data/|   |-[1] TOPDR: Subsea (Tops Depth Reference)',
#  'Tops_Data/|- data:',
#  'Tops_Data/|   |-[0] TOPT, M: Formation Top Depth',
#  'Tops_Data/|   |-[1] TOPB, M: Formation Base Depth',
#  'Tops_Data/|   |-[2] TOPN: Formation Top Name',
#  '|- Perforation_Data',
#  'Perforation_Data/|- parameters:',
#  'Perforation_Data/|   |-[0] PERFTYPE: 55 gr BIG HOLE (Charge Type)',
#  'Perforation_Data/|- data:',
#  'Perforation_Data/|   |-[0] PERFT, M: Perforation Top Depth',
#  'Perforation_Data/|   |-[1] PERFB, M: Perforation Bottom Depth',
#  'Perforation_Data/|   |-[2] PERFD, SHOTS/M: Shot density per meter']
