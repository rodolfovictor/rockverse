# %%
import ipyparallel as ipp

# Create an MPI cluster with 8 engines
cluster = ipp.Cluster(engines="mpi", n=8)

# Start and connect to the cluster
rc = cluster.start_and_connect_sync()

# Enable IPython magics for parallel processing
rc[:].activate()
# Out:
# Starting 8 engines with <class 'ipyparallel.cluster.launcher.MPIEngineSetLauncher'>
#   0%|          | 0/8 [00:00<?, ?engine/s]

# %%
# %%px --block
# import rockverse as rv
# import numpy as np
# self = rv.core.create_tensorfield(
#     data={(0, 0): np.random.rand(5,2,8).astype(float),
#             (2, 2): np.random.rand(5,2,8).astype(float),
#             },
#     chunks=(2,2,2),
#     #data = np.random.rand(5,2,8),
#     store=r"C:\Users\GOB7\Downloads\test",
#     #store='/u/gob7/test.zarr',
#     path="testpath",
#     name='test array',
#     unit='m/s',
#     description="UMA DESC",
#     latex_name=r"$ERF$",
#     latex_unit="MM",
#     coord_data=([1, 2, 4, 7, 9], [2, 2], None),
#     coord_names=("QQ", 'y','z'),
#     coord_units=('km', "S", "F"),
#     coord_descriptions=("UM", "DOIS", "WW"),
#     coord_latex_names=(r"$r$", r"$i$", r"$p$"),
#     coord_latex_units=('a', '', '.'),
#     overwrite=True)
# self.validate()
#
# #filename = '/u/gob7/test.h5'
# filename = r"C:\Users\GOB7\Downloads\test.h5"
# self.h5_dump(filename, path='/my/awesome/array', mode='w')
#
# #store='/u/gob7/test2.zarr'
# #store=r"C:\Users\GOB7\Downloads\test2"
# #h5path = '/myawesomearray'
# #path=None
# #overwrite=True
# #kwargs={}
# #with h5py.File(filename, mode='r') as fobj:
# #    self2 = load_array_from_h5_file(fobj, h5path, store, path=None, overwrite=True)
#
# #self.component[0]
# #self.component[0].zarray[...]
# #self.component[0][...]
# Out:
# %px:   0%|          | 0/8 [00:00<?, ?tasks/s]
# [7:execute]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import rockverse as rv
#       2 import numpy as np
# ----> 3 self = rv.core.create_tensorfield(
#       4     data={(0, 0): np.random.rand(5,2,8).astype(float),
#       5             (2, 2): np.random.rand(5,2,8).astype(float),
#       6             },
#       7     chunks=(2,2,2),
#       8     #data = np.random.rand(5,2,8),
#       9     store=r"C:\Users\GOB7\Downloads\test",
#      10     #store='/u/gob7/test.zarr',
#      11     path="testpath",
#      12     name='test array',
#      13     unit='m/s',
#      14     description="UMA DESC",
#      15     latex_name=r"$ERF$",
#      16     latex_unit="MM",
#      17     coord_data=([1, 2, 4, 7, 9], [2, 2], None),
#      18     coord_names=("QQ", 'y','z'),
#      19     coord_units=('km', "S", "F"),
#      20     coord_descriptions=("UM", "DOIS", "WW"),
#      21     coord_latex_names=(r"$r$", r"$i$", r"$p$"),
#      22     coord_latex_units=('a', '', '.'),
#      23     overwrite=True)
#      24 self.validate()
#      26 #filename = '/u/gob7/test.h5'
#
# File ~\Downloads\rockverse\src\rockverse\core\tensorfield.py:791, in create_tensorfield(data, store, path, chunks, name, unit, description, latex_name, latex_unit, coord_data, coord_names, coord_units, coord_descriptions, coord_latex_names, coord_latex_units, overwrite, zarr_group_args, zarr_array_args)
#     787     component_arrays = ["_".join(map(str, combo)) for combo in product(*ranges)]
#     789 for name in component_arrays:
#     790     temp = ParallelArray(
# --> 791         zgroup._zgroup.zeros(
#     792             name=f"component_{name}",
#     793             shape=shape,
#     794             chunks=chunks_,
#     795             dtype=type_,  # TODO specify in input parameters?
#     796             **kwargs))
#     797     ind = tuple(int(i) for i in name.split('_')) if name.find('_') >=0 else int(name)
#     798     if ind in components_keys:
#
# File ~\AppData\Local\miniforge3\envs\rockverse\Lib\site-packages\zarr\core\group.py:2699, in Group.zeros(self, name, shape, **kwargs)
#    2682 def zeros(self, *, name: str, shape: tuple[int, ...], **kwargs: Any) -> Array:
#    2683     """Create an array, with zero being used as the default value for uninitialized portions of the array.
#    2684
#    2685     Parameters
#    (...)
#    2697         The new array.
#    2698     """
# -> 2699     return Array(self._sync(self._async_group.zeros(name=name, shape=shape, **kwargs)))
#
# File ~\AppData\Local\miniforge3\envs\rockverse\Lib\site-packages\zarr\core\sync.py:208, in SyncMixin._sync(self, coroutine)
#     205 def _sync(self, coroutine: Coroutine[Any, Any, T]) -> T:
#     206     # TODO: refactor this to to take *args and **kwargs and pass those to the method
#     207     # this should allow us to better type the sync wrapper
# --> 208     return sync(
#     209         coroutine,
#     210         timeout=config.get("async.timeout"),
#     211     )
#
# File ~\AppData\Local\miniforge3\envs\rockverse\Lib\site-packages\zarr\core\sync.py:163, in sync(coro, loop, timeout)
#     160 return_result = next(iter(finished)).result()
#     162 if isinstance(return_result, BaseException):
# --> 163     raise return_result
#     164 else:
#     165     return return_result
#
# File ~\AppData\Local\miniforge3\envs\rockverse\Lib\site-packages\zarr\core\sync.py:119, in _runner(coro)
#     114 """
#     115 Await a coroutine and return the result of running it. If awaiting the coroutine raises an
#     116 exception, the exception will be returned.
#     117 """
#     118 try:
# --> 119     return await coro
#     120 except Exception as ex:
#     121     return ex
#
# File ~\AppData\Local\miniforge3\envs\rockverse\Lib\site-packages\zarr\core\group.py:1659, in AsyncGroup.zeros(self, name, shape, **kwargs)
#    1640 async def zeros(
#    1641     self, *, name: str, shape: tuple[int, ...], **kwargs: Any
#    1642 ) -> AsyncArray[ArrayV2Metadata] | AsyncArray[ArrayV3Metadata]:
#    1643     """Create an array, with zero being used as the default value for uninitialized portions of the array.
#    1644
#    1645     Parameters
#    (...)
#    1657         The new array.
#    1658     """
# -> 1659     return await async_api.zeros(shape=shape, store=self.store_path, path=name, **kwargs)
#
# File ~\AppData\Local\miniforge3\envs\rockverse\Lib\site-packages\zarr\api\asynchronous.py:1317, in zeros(shape, **kwargs)
#    1299 async def zeros(
#    1300     shape: tuple[int, ...], **kwargs: Any
#    1301 ) -> AsyncArray[ArrayV2Metadata] | AsyncArray[ArrayV3Metadata]:
#    1302     """Create an array, with zero being used as the default value for
#    1303     uninitialized portions of the array.
#    1304
#    (...)
#    1315         The new array.
#    1316     """
# -> 1317     return await create(shape=shape, fill_value=0, **kwargs)
#
# File ~\AppData\Local\miniforge3\envs\rockverse\Lib\site-packages\zarr\api\asynchronous.py:1055, in create(shape, chunks, dtype, compressor, fill_value, order, store, synchronizer, overwrite, path, chunk_store, filters, cache_metadata, cache_attrs, read_only, object_codec, dimension_separator, write_empty_chunks, zarr_version, zarr_format, meta_array, attributes, chunk_shape, chunk_key_encoding, codecs, dimension_names, storage_options, config, **kwargs)
#    1052         warnings.warn(ZarrUserWarning(msg), stacklevel=1)
#    1053     config_parsed = dataclasses.replace(config_parsed, write_empty_chunks=write_empty_chunks)
# -> 1055 return await AsyncArray._create(
#    1056     store_path,
#    1057     shape=shape,
#    1058     chunks=chunks,
#    1059     dtype=dtype,
#    1060     compressor=compressor,
#    1061     fill_value=fill_value,
#    1062     overwrite=overwrite,
#    1063     filters=filters,
#    1064     dimension_separator=dimension_separator,
#    1065     order=order,
#    1066     zarr_format=zarr_format,
#    1067     chunk_shape=chunk_shape,
#    1068     chunk_key_encoding=chunk_key_encoding,
#    1069     codecs=codecs,
#    1070     dimension_names=dimension_names,
#    1071     attributes=attributes,
#    1072     config=config_parsed,
#    1073     **kwargs,
#    1074 )
#
# File ~\AppData\Local\miniforge3\envs\rockverse\Lib\site-packages\zarr\core\array.py:672, in AsyncArray._create(cls, store, shape, dtype, zarr_format, fill_value, attributes, chunk_shape, chunk_key_encoding, codecs, dimension_names, chunks, dimension_separator, order, filters, compressor, overwrite, data, config)
#     669     if order is not None:
#     670         _warn_order_kwarg()
# --> 672     result = await cls._create_v3(
#     673         store_path,
#     674         shape=shape,
#     675         dtype=dtype_parsed,
#     676         chunk_shape=_chunks,
#     677         fill_value=fill_value,
#     678         chunk_key_encoding=chunk_key_encoding,
#     679         codecs=codecs,
#     680         dimension_names=dimension_names,
#     681         attributes=attributes,
#     682         overwrite=overwrite,
#     683         config=config_parsed,
#     684     )
#     685 elif zarr_format == 2:
#     686     if codecs is not None:
#
# File ~\AppData\Local\miniforge3\envs\rockverse\Lib\site-packages\zarr\core\array.py:826, in AsyncArray._create_v3(cls, store_path, shape, dtype, chunk_shape, config, fill_value, chunk_key_encoding, codecs, dimension_names, attributes, overwrite)
#     814 metadata = cls._create_metadata_v3(
#     815     shape=shape,
#     816     dtype=dtype,
#    (...)
#     822     attributes=attributes,
#     823 )
#     825 array = cls(metadata=metadata, store_path=store_path, config=config)
# --> 826 await array._save_metadata(metadata, ensure_parents=True)
#     827 return array
#
# File ~\AppData\Local\miniforge3\envs\rockverse\Lib\site-packages\zarr\core\array.py:1650, in AsyncArray._save_metadata(self, metadata, ensure_parents)
#    1640     for parent in parents:
#    1641         awaitables.extend(
#    1642             [
#    1643                 (parent.store_path / key).set_if_not_exists(value)
#    (...)
#    1647             ]
#    1648         )
# -> 1650 await gather(*awaitables)
#
# File ~\AppData\Local\miniforge3\envs\rockverse\Lib\site-packages\zarr\abc\store.py:524, in set_or_delete(byte_setter, value)
#     522     await byte_setter.delete()
#     523 else:
# --> 524     await byte_setter.set(value)
#
# File ~\AppData\Local\miniforge3\envs\rockverse\Lib\site-packages\zarr\storage\_common.py:184, in StorePath.set(self, value, byte_range)
#     182 if byte_range is not None:
#     183     raise NotImplementedError("Store.set does not have partial writes yet")
# --> 184 await self.store.set(self.path, value)
#
# File ~\AppData\Local\miniforge3\envs\rockverse\Lib\site-packages\zarr\storage\_local.py:206, in LocalStore.set(self, key, value)
#     204 async def set(self, key: str, value: Buffer) -> None:
#     205     # docstring inherited
# --> 206     return await self._set(key, value)
#
# File ~\AppData\Local\miniforge3\envs\rockverse\Lib\site-packages\zarr\storage\_local.py:225, in LocalStore._set(self, key, value, exclusive)
#     221     raise TypeError(
#     222         f"LocalStore.set(): `value` must be a Buffer instance. Got an instance of {type(value)} instead."
#     223     )
#     224 path = self.root / key
# --> 225 await asyncio.to_thread(_put, path, value, start=None, exclusive=exclusive)
#
# File ~\AppData\Local\miniforge3\envs\rockverse\Lib\asyncio\threads.py:25, in to_thread(func, *args, **kwargs)
#      23 ctx = contextvars.copy_context()
#      24 func_call = functools.partial(ctx.run, func, *args, **kwargs)
# ---> 25 return await loop.run_in_executor(None, func_call)
#
# File ~\AppData\Local\miniforge3\envs\rockverse\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File ~\AppData\Local\miniforge3\envs\rockverse\Lib\site-packages\zarr\storage\_local.py:63, in _put(path, value, start, exclusive)
#      61 else:
#      62     mode = "wb"
# ---> 63 with path.open(mode=mode) as f:
#      64     # write takes any object supporting the buffer protocol
#      65     return f.write(view)
#
# File ~\AppData\Local\miniforge3\envs\rockverse\Lib\pathlib.py:1013, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1011 if "b" not in mode:
#    1012     encoding = io.text_encoding(encoding)
# -> 1013 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\GOB7\\Downloads\\test\\testpath\\component_0_0\\zarr.json'
