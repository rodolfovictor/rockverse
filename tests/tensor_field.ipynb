# %%
import ipyparallel as ipp

# Create an MPI cluster with 8 engines
cluster = ipp.Cluster(engines="mpi", n=2)

# Start and connect to the cluster
rc = cluster.start_and_connect_sync()

# Enable IPython magics for parallel processing
rc[:].activate()
# Out:
# Starting 2 engines with <class 'ipyparallel.cluster.launcher.MPIEngineSetLauncher'>
#   0%|          | 0/2 [00:00<?, ?engine/s]

# %%
# %%px --block
# import rockverse as rv
# import numpy as np
# self = rv.core.create_tensorfield(
#     data={(0, 0): np.random.rand(4,4).astype(float),
#           (2, 2): np.random.rand(4,4).astype(float),
#             },
#     chunks=(2,2),
#     #data = np.random.rand(5,2,8),
#     store=r"C:\Users\GOB7\Downloads\test",
#     #store='/u/gob7/test.zarr',
#     path="testpath",
#     name='test array',
#     unit='m/s',
#     description="UMA DESC",
#     latex_name=r"$ERF$",
#     latex_unit="MM",
#     coord_data=([1, 2, 4, 7], [2, 3, 4, 5]),
#     coord_names=("QQ", 'y'),
#     coord_units=('km', "S"),
#     coord_descriptions=("UM", "WW"),
#     coord_latex_names=(r"$r$", r"$p$"),
#     coord_latex_units=('a', '.'),
#     overwrite=True)
# #TESTANDO PARALLEL COMPONENTS <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# self.validate()
#
# #filename = '/u/gob7/test.h5'
# #filename = r"C:\Users\GOB7\Downloads\test.h5"
# #self.h5_dump(filename, path='/my/awesome/array', mode='w')
#
# #store='/u/gob7/test2.zarr'
# #store=r"C:\Users\GOB7\Downloads\test2"
# #h5path = '/myawesomearray'
# #path=None
# #overwrite=True
# #kwargs={}
# #with h5py.File(filename, mode='r') as fobj:
# #    self2 = load_array_from_h5_file(fobj, h5path, store, path=None, overwrite=True)
#
# #self.components[0]
# #self.components[0].zarray[...]
# #self.components[0][...]
# Out:
# [stdout:0] 0 fill block 0 (0,)
# 0 fill block 0 (0,)
# 0 fill block 0 (0, 0)
# 0 fill block 2 (1, 0)
# 0 fill block 0 (0, 0)
# 0 fill block 2 (1, 0)
# [stdout:1] 1 fill block 1 (0, 1)
# 1 fill block 3 (1, 1)
# 1 fill block 1 (0, 1)
# 1 fill block 3 (1, 1)

# %%
# %%px --block
# a=self.components[0,0]

# %%
# %%px --block
# rv.core.ParallelArray(a.zarray).zarray[...]
# Out:
# Out[1:7]:
# array([[0.98302163, 0.91377736, 0.14570259, 0.1248589 ],
#        [0.79295011, 0.36252804, 0.08805019, 0.70834946],
#        [0.59328376, 0.72595596, 0.88954024, 0.60603255],
#        [0.27433365, 0.85605409, 0.49909254, 0.91345392]])
# Out[0:7]:
# array([[0.98302163, 0.91377736, 0.14570259, 0.1248589 ],
#        [0.79295011, 0.36252804, 0.08805019, 0.70834946],
#        [0.59328376, 0.72595596, 0.88954024, 0.60603255],
#        [0.27433365, 0.85605409, 0.49909254, 0.91345392]])
# Output for ipengine-1758309098-xiev-1758309099-3372:
# 2025-09-19 16:11:40.386 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-09-19 16:11:40.386 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-09-19 16:11:40.386 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-09-19 16:11:40.386 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-09-19 16:11:40.401 [IPEngine.1] Registering with controller at tcp://127.0.0.1:50690
# 2025-09-19 16:11:40.401 [IPEngine.0] Registering with controller at tcp://127.0.0.1:50690
# 2025-09-19 16:11:40.406 [IPEngine.1] Requesting id: 1
# 2025-09-19 16:11:40.406 [IPEngine.0] Requesting id: 0
# C:\Users\GOB7\AppData\Local\miniforge3\envs\rockverse\Lib\site-packages\zmq\_future.py:718: RuntimeWarning: Proactor event loop does not implement add_reader family of methods required for zmq. Registering an additional selector thread for add_reader support via tornado. Use `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())` to avoid this warning.
#   self._get_loop()
# C:\Users\GOB7\AppData\Local\miniforge3\envs\rockverse\Lib\site-packages\zmq\_future.py:718: RuntimeWarning: Proactor event loop does not implement add_reader family of methods required for zmq. Registering an additional selector thread for add_reader support via tornado. Use `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())` to avoid this warning.
#   self._get_loop()
# 2025-09-19 16:11:40.425 [IPEngine.1.1] Shell_addrs: ['tcp://127.0.0.1:50692', 'tcp://127.0.0.1:50693', 'tcp://127.0.0.1:50698']
# 2025-09-19 16:11:40.425 [IPEngine.0.0] Shell_addrs: ['tcp://127.0.0.1:50692', 'tcp://127.0.0.1:50693', 'tcp://127.0.0.1:50697']
# 2025-09-19 16:11:40.426 [IPEngine.1.1] Connecting shell to tcp://127.0.0.1:50692
# 2025-09-19 16:11:40.426 [IPEngine.1.1] Connecting shell to tcp://127.0.0.1:50693
# 2025-09-19 16:11:40.426 [IPEngine.1.1] Connecting shell to tcp://127.0.0.1:50698
# 2025-09-19 16:11:40.426 [IPEngine.1.1] Starting nanny
# 2025-09-19 16:11:40.426 [IPEngine.0.0] Connecting shell to tcp://127.0.0.1:50692
# 2025-09-19 16:11:40.426 [IPEngine.0.0] Connecting shell to tcp://127.0.0.1:50693
# 2025-09-19 16:11:40.426 [IPEngine.0.0] Connecting shell to tcp://127.0.0.1:50697
# 2025-09-19 16:11:40.426 [IPEngine.0.0] Starting nanny
# 2025-09-19 16:11:41.261 [KernelNanny.1] Starting kernel nanny for engine 1, pid=33816, nanny pid=26212
# 2025-09-19 16:11:41.261 [KernelNanny.0] Starting kernel nanny for engine 0, pid=20992, nanny pid=33380
# 2025-09-19 16:11:41.262 [KernelNanny.1] Nanny watching parent pid 33816.
# 2025-09-19 16:11:41.262 [KernelNanny.0] Nanny watching parent pid 20992.
# 2025-09-19 16:11:41.423 [IPEngine.0.0] Loading IPython extension: storemagic
# 2025-09-19 16:11:41.423 [IPEngine.1.1] Loading IPython extension: storemagic
# 2025-09-19 16:11:41.424 [IPEngine.0.0] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2025-09-19 16:11:41.424 [IPEngine.1.1] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2025-09-19 16:11:41.426 [IPEngine.1.1] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-09-19 16:11:41.426 [IPEngine.0.0] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-09-19 16:11:41.440 [IPEngine.1.1] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-09-19 16:11:41.440 [IPEngine.1.1] Completed registration with id 1
# 2025-09-19 16:11:41.441 [IPEngine.0.0] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-09-19 16:11:41.441 [IPEngine.0.0] Completed registration with id 0
# 2025-09-19 16:11:46.416 [IPEngine.0.0] Handling execute_request: 1f5ac422-41fd557308a0dd3be7e0c53c_3372_1
# 2025-09-19 16:11:46.416 [IPEngine.1.1] Handling execute_request: 1f5ac422-41fd557308a0dd3be7e0c53c_3372_2
# 2025-09-19 16:11:48.079 [IPEngine.0.0] Handling execute_request: 1f5ac422-41fd557308a0dd3be7e0c53c_3372_3
# 2025-09-19 16:11:48.079 [IPEngine.1.1] Handling execute_request: 1f5ac422-41fd557308a0dd3be7e0c53c_3372_4
# 2025-09-19 16:11:48.097 [IPEngine.0.0] Handling execute_request: 1f5ac422-41fd557308a0dd3be7e0c53c_3372_5
# 2025-09-19 16:11:48.097 [IPEngine.1.1] Handling execute_request: 1f5ac422-41fd557308a0dd3be7e0c53c_3372_6
# 2025-09-19 16:12:00.796 [IPEngine.0.0] Handling execute_request: 1f5ac422-41fd557308a0dd3be7e0c53c_3372_7
# 2025-09-19 16:12:00.796 [IPEngine.1.1] Handling execute_request: 1f5ac422-41fd557308a0dd3be7e0c53c_3372_8
# 2025-09-19 16:12:32.286 [IPEngine.0.0] Handling execute_request: 1f5ac422-41fd557308a0dd3be7e0c53c_3372_9
# 2025-09-19 16:12:32.286 [IPEngine.1.1] Handling execute_request: 1f5ac422-41fd557308a0dd3be7e0c53c_3372_10
# 2025-09-19 16:12:38.309 [IPEngine.0.0] Handling execute_request: 1f5ac422-41fd557308a0dd3be7e0c53c_3372_11
# 2025-09-19 16:12:38.309 [IPEngine.1.1] Handling execute_request: 1f5ac422-41fd557308a0dd3be7e0c53c_3372_12
# 2025-09-19 16:12:41.131 [IPEngine.0.0] Handling execute_request: 1f5ac422-41fd557308a0dd3be7e0c53c_3372_13
# 2025-09-19 16:12:41.131 [IPEngine.1.1] Handling execute_request: 1f5ac422-41fd557308a0dd3be7e0c53c_3372_14
#
# engine set stopped 1758309099: {'exit_code': 15, 'pid': 8568, 'identifier': 'ipengine-1758309098-xiev-1758309099-3372'}
# Output for ipcontroller-1758309098-xiev-3372:
# 2025-09-19 16:11:38.961 [IPController] Hub listening on tcp://127.0.0.1:50690 for registration.
# 2025-09-19 16:11:38.967 [IPController] Hub using DB backend: DictDB
# 2025-09-19 16:11:39.224 [IPController] hub::created hub
# 2025-09-19 16:11:39.224 [IPController] writing connection info to C:\Users\GOB7\.ipython\profile_default\security\ipcontroller-1758309098-xiev-client.json
# 2025-09-19 16:11:39.224 [IPController] writing connection info to C:\Users\GOB7\.ipython\profile_default\security\ipcontroller-1758309098-xiev-engine.json
# 2025-09-19 16:11:39.225 [IPController] task::using Python leastload Task scheduler
# 2025-09-19 16:11:39.339 [IPController] Heartmonitor beating every 3000ms
# 2025-09-19 16:11:39.387 [IPController] client::client b'\x00\x80\x00\x00)' requested 'connection_request'
# 2025-09-19 16:11:39.387 [IPController] client::client [b'\x00\x80\x00\x00)'] connected
# 2025-09-19 16:11:40.290 [broadcast-00] BroadcastScheduler 00 started
# 2025-09-19 16:11:40.291 [broadcast-0] BroadcastScheduler 0 started
# 2025-09-19 16:11:40.292 [broadcast-01] BroadcastScheduler 01 started
# 2025-09-19 16:11:40.343 [task] Task scheduler started [leastload]
# 2025-09-19 16:11:40.348 [IPController] client::client b'\x00\x80\x00\x00-' requested 'connection_request'
# 2025-09-19 16:11:40.348 [IPController] client::client [b'\x00\x80\x00\x00-'] connected
# 2025-09-19 16:11:40.380 [IPController] heartbeat::waiting for subscription
# 2025-09-19 16:11:40.380 [IPController] heartbeat::subscription started
# 2025-09-19 16:11:40.424 [IPController] client::client b'20f3b25f-38f8b0b64f266cbda7c4cd10' requested 'registration_request'
# 2025-09-19 16:11:40.424 [IPController] registration::accepting registration 1:20f3b25f-38f8b0b64f266cbda7c4cd10
# 2025-09-19 16:11:40.424 [IPController] client::client b'958c40bf-18659b5c0631162ef7128b4a' requested 'registration_request'
# 2025-09-19 16:11:40.425 [IPController] registration::accepting registration 0:958c40bf-18659b5c0631162ef7128b4a
# 2025-09-19 16:11:46.395 [IPController] Notifying hub of 2 new hearts
# 2025-09-19 16:11:46.400 [IPController] Registering 2 new hearts
# 2025-09-19 16:11:46.400 [IPController] registration::finished registering engine 0:958c40bf-18659b5c0631162ef7128b4a in 5968ms
# 2025-09-19 16:11:46.401 [IPController] engine::Engine Connected: 0
# 2025-09-19 16:11:46.402 [IPController] registration::finished registering engine 1:20f3b25f-38f8b0b64f266cbda7c4cd10 in 5968ms
# 2025-09-19 16:11:46.402 [IPController] engine::Engine Connected: 1
# 2025-09-19 16:11:46.416 [IPController] queue::client b'\x00\x80\x00\x00)' submitted request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_1' to 0
# 2025-09-19 16:11:46.416 [IPController] queue::client b'\x00\x80\x00\x00)' submitted request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_2' to 1
# 2025-09-19 16:11:48.071 [IPController] queue::request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_1' completed on 0
# 2025-09-19 16:11:48.072 [IPController] queue::request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_2' completed on 1
# 2025-09-19 16:11:48.078 [IPController] queue::client b'\x00\x80\x00\x00)' submitted request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_3' to 0
# 2025-09-19 16:11:48.079 [IPController] queue::client b'\x00\x80\x00\x00)' submitted request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_4' to 1
# 2025-09-19 16:11:48.092 [IPController] queue::request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_3' completed on 0
# 2025-09-19 16:11:48.093 [IPController] queue::request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_4' completed on 1
# 2025-09-19 16:11:48.097 [IPController] queue::client b'\x00\x80\x00\x00)' submitted request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_5' to 0
# 2025-09-19 16:11:48.097 [IPController] queue::client b'\x00\x80\x00\x00)' submitted request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_6' to 1
# 2025-09-19 16:11:48.124 [IPController] queue::request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_5' completed on 0
# 2025-09-19 16:11:48.124 [IPController] queue::request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_6' completed on 1
# 2025-09-19 16:12:00.796 [IPController] queue::client b'\x00\x80\x00\x00)' submitted request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_7' to 0
# 2025-09-19 16:12:00.796 [IPController] queue::client b'\x00\x80\x00\x00)' submitted request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_8' to 1
# 2025-09-19 16:12:00.802 [IPController] queue::request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_8' completed on 1
# 2025-09-19 16:12:00.802 [IPController] queue::request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_7' completed on 0
# 2025-09-19 16:12:32.286 [IPController] queue::client b'\x00\x80\x00\x00)' submitted request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_9' to 0
# 2025-09-19 16:12:32.286 [IPController] queue::client b'\x00\x80\x00\x00)' submitted request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_10' to 1
# 2025-09-19 16:12:32.290 [IPController] queue::request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_10' completed on 1
# 2025-09-19 16:12:32.291 [IPController] queue::request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_9' completed on 0
# 2025-09-19 16:12:38.309 [IPController] queue::client b'\x00\x80\x00\x00)' submitted request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_11' to 0
# 2025-09-19 16:12:38.309 [IPController] queue::client b'\x00\x80\x00\x00)' submitted request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_12' to 1
# 2025-09-19 16:12:38.314 [IPController] queue::request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_11' completed on 0
# 2025-09-19 16:12:38.314 [IPController] queue::request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_12' completed on 1
# 2025-09-19 16:12:41.131 [IPController] queue::client b'\x00\x80\x00\x00)' submitted request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_13' to 0
# 2025-09-19 16:12:41.132 [IPController] queue::client b'\x00\x80\x00\x00)' submitted request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_14' to 1
# 2025-09-19 16:12:41.138 [IPController] queue::request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_14' completed on 1
# 2025-09-19 16:12:41.138 [IPController] queue::request '1f5ac422-41fd557308a0dd3be7e0c53c_3372_13' completed on 0
#
# Controller stopped: {'exit_code': 15, 'pid': 32800, 'identifier': 'ipcontroller-1758309098-xiev-3372'}
